# %% [markdown]
# # 생물정보학 및 실습 1 - Term Project용 Mission 2 환경 셋업

# %% [markdown]
# ```
# 생물정보학 및 실습 1
# 서울대학교 생물정보학전공/생명과학부 2023년 1학기
#
# 이 노트북은 Creative Commons BY-SA 조건으로 재사용 가능합니다.
# 장혜식 <hyeshik@snu.ac.kr>, 서울대학교 생명과학부
# ```
#
# 이 노트북은 Google Colab을 이용해서 Term Project를 할 수 있도록 환경을 준비해 줍니다. 터미널 사용이 원활하지 않은 상태이고, 데이터를 오랫동안 보관하기 어렵기 때문에 되도록 개인용 컴퓨터에서 [Anaconda](https://www.anaconda.com/)나 [JupyterLab](https://jupyterlab.readthedocs.io/en/stable/) 등을 설치하고 사용하시는 것이 편하지만, 개인용 컴퓨터 사양이 부족한 경우에는 Google CoLab을 사용할 수도 있습니다. 개인용 컴퓨터를 쓸 때는 Windows에서는 [WSL2](https://docs.microsoft.com/en-us/windows/wsl/install-win10)를 쓰시면 리눅스 커맨드라인 환경을 쓸 수 있습니다. Google Colab은 창을 닫은 후 90분 후, 또는 창을 처음 열고 12시간 후에 환경을 닫아버리기 때문에 매번 실습할 때마다 새로 셋업이 필요합니다. `Runtime->Run All`을 실행해서 전체를 한 번 실행하시면 준비됩니다. 모든 것이 잘 안 되고 뭔가 꼬인 느낌이 강하게 들 때는 `Runtime->Factory reset runtime`을 누르고 새로 시작하시면 될 수도 있습니다.

# %% [markdown]
# ## Google Drive 마운트
#
# 데이터 파일들을 불러오고 저장하기 위해서 Google Drive를 연결합니다. 화면에 나오는 주소를 눌러서 인증하고 인증 코드를 그 아래에 입력하세요. 그러면 `/contents/drive/MyDrive`에서 자신의 Drive 최상단 폴더가 보입니다. Google CoLab에서 접속하지 않고, 본인 컴퓨터 또는 연구실 워크스테이션 등 다른 컴퓨터를 쓰시는 경우에는 저장공간이 충분하므로 이 부분은 생략하고 지나갑니다.

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ## 실습용 Bioconda 환경 설치하기
# Google CoLab에서 접속하지 않고, 본인 컴퓨터 또는 연구실 워크스테이션 등 다른 컴퓨터를 쓰시는 경우에는 따로 실습용 [Bioconda](https://bioconda.github.io/) 환경을 구축해서 이 노트북을 그 환경 안에서 띄우시면 됩니다.
#
# CoLab을 쓰시는 분들은 다음에 따라서 실습용 프로그램들을 쉽게 설치할 수 있도록 [Bioconda](https://bioconda.github.io/) 환경을 만듭니다. 실행하고 진행상황을 관찰하다가 에러로 보이는 것이 있으면 잘 읽어보고 해결합니다.
#
# 파이썬 모듈들은 Colab쪽의 파이썬 인터프리터를 바꿀 수 없기 때문에 Conda에 설치하더라도 사용하기 어렵습니다. 파이썬 모듈은 `pip` 명령어로 설치하시면 Colab에서 불러와서 사용할 수 있습니다.
#
# 환경 초기화에 관련된 스크립트는 [GitHub 프로젝트](https://github.com/hyeshik/colab-biolab)에 있습니다.

# %%
# !git clone https://github.com/hyeshik/colab-biolab.git
# !cd colab-biolab && bash tools/setup.sh
exec(open('colab-biolab/tools/activate_conda.py').read())

# %% [markdown]
# 설정이 끝났으면, 이제 콘솔을 열어서 터미널로 접속할 수 있는 통로를 열어줍니다.

# %% [markdown]
# ## 시퀀싱 데이터 다운로드
# 첫 실습 시간에 데이터 복사를 마쳤으면 이 부분은 생략하고 지나갑니다.
#
# 이제 실습 수업에서 필요한 시퀀싱 데이터를 다운로드 받아서 설치합시다. 드라이브 공간만 충분하면 데이터는 계속 저장돼 있기 때문에 학기 전체를 통해서 딱 한 번만 하시면 됩니다. Colab에서는 작업용 데이터를 Google Drive 폴더 아래의 `binfo-datapack1`에 저장합니다. 실습용 데이터는 `/content/drive/MyDrive/binfo1-datapack1`에 풀리게 됩니다.
#
# ### (Option 1) Google CoLab에서 접속한 경우
# 1. [Google Drive 공유폴더](https://drive.google.com/drive/folders/1QBJednh-C7A17PFOlpZHBKyDmBvd6klh?usp=sharing)에 접속합니다.
# 1. 중간 제목줄의 "binfo1-datapack1 ▾"에서 ▾을 누릅니다.
# 1. Add shortcut to Drive를 누릅니다.
# 1. My Drive를 선택해서 ADD SHORTCUT 버튼을 누릅니다.
# 1. 다음 cell을 실행해서 링크가 제대로 들어왔는지 확인합니다. (바로 확인되지 않으면 3–5분 정도 기다렸다가 하면 됩니다.)
# 1. 제대로 확인되면 다음으로 넘어갑니다.

# %%
# !ls -al /content/drive/MyDrive/binfo1-datapack1/

# %% [markdown]
# ### (Option 2) CoLab외의 다른 환경에서 접속한 경우
# 본인 컴퓨터나 연구실 워크스테이션 등에서 작업하는 경우에는 다음 명령어로 다운로드 받으시면 됩니다. 첫 번째에는 wget이 접속오류를 내는 경우가 많으니, 접속에러가 발생하면 다시 한 번 실행해 보세요. `/content/drive/Mydrive` 부분은 원하는 저장 경로로 바꿔서 지정하시면 됩니다.

# %%
# !wget -O - --no-check-certificate https://hyeshik.qbio.io/binfo/binfo1-datapack1.tar | tar -C /Users/steineggerlab/Desktop/lecture/bioinf1 -xf -
# Out:
# --2023-05-07 14:41:40--  https://hyeshik.qbio.io/binfo/binfo1-datapack1.tar
# Resolving hyeshik.qbio.io (hyeshik.qbio.io)... 147.47.203.129
# Connecting to hyeshik.qbio.io (hyeshik.qbio.io)|147.47.203.129|:443... connected.
# WARNING: cannot verify hyeshik.qbio.io's certificate, issued by 'CN=R3,O=Let\'s Encrypt,C=US':
#   Unable to locally verify the issuer's authority.
# HTTP request sent, awaiting response... 200 OK
# Length: 6424668160 (6.0G) [application/octet-stream]
# Saving to: 'STDOUT'
#
# -                    16%[==>                 ]   1.01G  16.4MB/s    in 62s
#
# 2023-05-07 14:42:42 (16.5 MB/s) - Connection closed at byte 1082490581. Retrying.
#
# --2023-05-07 14:42:43--  (try: 2)  https://hyeshik.qbio.io/binfo/binfo1-datapack1.tar
# Connecting to hyeshik.qbio.io (hyeshik.qbio.io)|147.47.203.129|:443... connected.
# Unable to establish SSL connection.
# binfo1-datapack1/CLIP-35L33G.bam: Truncated tar archive
# tar: Error exit delayed from previous errors.

# %% [markdown]
# 그리고, GENCODE Annotation 데이터도 미리 받아서 저장해 둡니다. 에러가 나면 다시 한 번 실행해 봅니다.

# %%
# !wget --no-check-certificate -O /Users/steineggerlab/Desktop/lecture/bioinf1/binfo1-datapack1/gencode.gtf.gz http://ftp.ebi.ac.uk/pub/databases/gencode/Gencode_mouse/release_M27/gencode.vM27.annotation.gtf.gz
# Out:
# --2023-05-07 14:56:33--  http://ftp.ebi.ac.uk/pub/databases/gencode/Gencode_mouse/release_M27/gencode.vM27.annotation.gtf.gz
# Resolving ftp.ebi.ac.uk (ftp.ebi.ac.uk)... 193.62.193.138
# Connecting to ftp.ebi.ac.uk (ftp.ebi.ac.uk)|193.62.193.138|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 28359457 (27M) [application/x-gzip]
# Saving to: '/Users/steineggerlab/Desktop/lecture/bioinf1/binfo1-datapack1/gencode.gtf.gz'
#
# /Users/steineggerla 100%[===================>]  27.04M   215KB/s    in 2m 25s
#
# 2023-05-07 14:58:59 (192 KB/s) - '/Users/steineggerlab/Desktop/lecture/bioinf1/binfo1-datapack1/gencode.gtf.gz' saved [28359457/28359457]

# %% [markdown]
# 다루기 쉽도록 Annotation 압축을 풉니다.

# %%
# !gunzip /Users/steineggerlab/Desktop/lecture/bioinf1/binfo1-datapack1/gencode.gtf.gz

# %% [markdown]
# ### 파일 체크섬 확인
#
# 받은 데이터의 MD5 체크섬을 확인합니다. 한참 걸립니다. 각 파일들의 원래 체크섬은 다음과 같습니다. 한 번 비교해 보세요.
#
# ```
# 140aaf30bcb9276cc716f8699f04ddd6  CLIP-35L33G.bam
# f1b3336ed7e2f97d562dcc71641251bd  CLIP-35L33G.bam.bai
# 328883a73d507eafbf5b60bd6b906201  RNA-control.bam
# 02073818e2f398a73c3b76e5169de1ca  RNA-control.bam.bai
# b09550d09d6c2a4ce27f0226f426fdb1  RNA-siLin28a.bam
# fef112c727244060ea62d3f2564a07f6  RNA-siLin28a.bam.bai
# 28bbd0c47d725669340c784f1b772c01  RNA-siLuc.bam
# 43590fdc4d81905c0432e0d1cb8cfd5b  RNA-siLuc.bam.bai
# 5c08a9297307bc83259e658c4474f0cc  RPF-siLin28a.bam
# a1bb3e29be412dfd7fd8d16b1b1acc4c  RPF-siLin28a.bam.bai
# f2eebf50943024d0116c9cd3e744c707  RPF-siLuc.bam
# dc24f69e8f571fc8be30f28ce5b84fcd  RPF-siLuc.bam.bai
# ```

# %%
# !md5sum /Users/steineggerlab/Desktop/lecture/bioinf1/binfo1-datapack1/*
# Out:
# 140aaf30bcb9276cc716f8699f04ddd6  /Users/steineggerlab/Desktop/lecture/bioinf1/binfo1-datapack1/CLIP-35L33G.bam
# f1b3336ed7e2f97d562dcc71641251bd  /Users/steineggerlab/Desktop/lecture/bioinf1/binfo1-datapack1/CLIP-35L33G.bam.bai
# 328883a73d507eafbf5b60bd6b906201  /Users/steineggerlab/Desktop/lecture/bioinf1/binfo1-datapack1/RNA-control.bam
# 02073818e2f398a73c3b76e5169de1ca  /Users/steineggerlab/Desktop/lecture/bioinf1/binfo1-datapack1/RNA-control.bam.bai
# b09550d09d6c2a4ce27f0226f426fdb1  /Users/steineggerlab/Desktop/lecture/bioinf1/binfo1-datapack1/RNA-siLin28a.bam
# fef112c727244060ea62d3f2564a07f6  /Users/steineggerlab/Desktop/lecture/bioinf1/binfo1-datapack1/RNA-siLin28a.bam.bai
# 28bbd0c47d725669340c784f1b772c01  /Users/steineggerlab/Desktop/lecture/bioinf1/binfo1-datapack1/RNA-siLuc.bam
# 43590fdc4d81905c0432e0d1cb8cfd5b  /Users/steineggerlab/Desktop/lecture/bioinf1/binfo1-datapack1/RNA-siLuc.bam.bai
# 5c08a9297307bc83259e658c4474f0cc  /Users/steineggerlab/Desktop/lecture/bioinf1/binfo1-datapack1/RPF-siLin28a.bam
# a1bb3e29be412dfd7fd8d16b1b1acc4c  /Users/steineggerlab/Desktop/lecture/bioinf1/binfo1-datapack1/RPF-siLin28a.bam.bai
# f2eebf50943024d0116c9cd3e744c707  /Users/steineggerlab/Desktop/lecture/bioinf1/binfo1-datapack1/RPF-siLuc.bam
# dc24f69e8f571fc8be30f28ce5b84fcd  /Users/steineggerlab/Desktop/lecture/bioinf1/binfo1-datapack1/RPF-siLuc.bam.bai
# d54d428f5872030c4ffc43058709b896  /Users/steineggerlab/Desktop/lecture/bioinf1/binfo1-datapack1/gencode.gtf

# %%
# !ls -al /Users/steineggerlab/Desktop/lecture/bioinf1/binfo1-datapack1
# Out:
# total 14357896
# drwxr-xr-x  15 steineggerlab  staff         480 May  7 14:59 .
# drwxr-xr-x   9 steineggerlab  staff         288 May  7 14:57 ..
# -rw-r--r--   1 steineggerlab  staff  1370036258 May  6  2021 CLIP-35L33G.bam
# -rw-r--r--   1 steineggerlab  staff     3118336 May  6  2021 CLIP-35L33G.bam.bai
# -rw-r--r--   1 steineggerlab  staff  1003658801 May  6  2021 RNA-control.bam
# -rw-r--r--   1 steineggerlab  staff     2276104 May  6  2021 RNA-control.bam.bai
# -rw-r--r--   1 steineggerlab  staff  1260991122 May  6  2021 RNA-siLin28a.bam
# -rw-r--r--   1 steineggerlab  staff     2710744 May  6  2021 RNA-siLin28a.bam.bai
# -rw-r--r--   1 steineggerlab  staff   981684502 May  6  2021 RNA-siLuc.bam
# -rw-r--r--   1 steineggerlab  staff     2606104 May  6  2021 RNA-siLuc.bam.bai
# -rw-r--r--   1 steineggerlab  staff   737352902 May  6  2021 RPF-siLin28a.bam
# -rw-r--r--   1 steineggerlab  staff     2482768 May  6  2021 RPF-siLin28a.bam.bai
# -rw-r--r--   1 steineggerlab  staff  1055123479 May  6  2021 RPF-siLuc.bam
# -rw-r--r--   1 steineggerlab  staff     2605912 May  6  2021 RPF-siLuc.bam.bai
# -rw-r--r--   1 steineggerlab  staff   883334756 Mar  9  2021 gencode.gtf

# %% [markdown]
# # 파일 복사하기
# 첫 시간에 파일을 복사해 두었으면 이 부분은 생략하고 다음으로 넘어갑니다.
#
# 공유한 폴더를 나의 작업 폴더로 복사합니다.

# %%
# !mkdir -p /Users/steineggerlab/Desktop/lecture/bioinf1/binfo1-work2
# %cd /Users/steineggerlab/Desktop/lecture/bioinf1/binfo1-work2
# !cp ../binfo1-datapack1/* .
# Out:
# /Users/steineggerlab/Desktop/lecture/bioinf1/binfo1-work2

# %% [markdown]
# # 프로그램 설치
# 데이터 준비가 끝났으면, 이제 이번 시간 실습에 필요한 프로그램들 몇 가지를 추가로 설치합니다.

# %%
# !conda install -y bedtools bioawk samtools
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: failed with repodata from current_repodata.json, will retry with next repodata source.
# Collecting package metadata (repodata.json): done
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: /
# Found conflicts! Looking for incompatible packages.
# This can take several minutes.  Press CTRL-C to abort.
#                                                                                                                                                                |failed
#
# UnsatisfiableError: The following specifications were found
# to be incompatible with the existing python installation in your environment:
#
# Specifications:
#
#   - defaults/noarch::asttokens==2.0.5=pyhd3eb1b0_0 -> python[version='2.7.*|3.5.*|3.6.*|>=2.7,<2.8.0a0|>=3.6,<3.7.0a0|>=3.8,<3.9.0a0|>=3.7,<3.8.0a0|3.4.*|>=3.9,<3.10.0a0|>=3.5,<3.6.0a0']
#   - defaults/noarch::pexpect==4.8.0=pyhd3eb1b0_3 -> python[version='2.7.*|3.5.*|3.6.*|>=2.7,<2.8.0a0|>=3.5,<3.6.0a0|>=3.6,<3.7.0a0|>=3.7,<3.8.0a0|3.4.*|>=3.8,<3.9.0a0']
#   - defaults/noarch::python-dateutil==2.8.2=pyhd3eb1b0_0 -> python[version='2.7.*|3.5.*|3.6.*|>=2.7,<2.8.0a0|>=3.6,<3.7.0a0|>=3.8,<3.9.0a0|>=3.7,<3.8.0a0|3.4.*|>=3.9,<3.10.0a0|>=3.5,<3.6.0a0']
#   - defaults/osx-arm64::argon2-cffi-bindings==21.2.0=py310h1a28f6b_0 -> python[version='2.7.*|3.5.*|3.6.*|3.6.12|3.6.12|3.7.10|3.7.10|3.7.12|3.8.12|3.8.16|3.9.16|>=3.11,<3.12.0a0|>=3.8,<3.9.0a0|>=3.9,<3.10.0a0|>=3.7,<3.8.0a0|3.9.10|>=3.6,<3.7.0a0|3.7.9|3.6.9|3.6.9|3.6.9|>=2.7,<2.8.0a0|3.6.9|>=3.5,<3.6.0a0|3.4.*',build='0_73_pypy|2_73_pypy|5_73_pypy|5_73_pypy|1_73_pypy|0_73_pypy|0_73_pypy|4_73_pypy|3_73_pypy|1_73_pypy']
#   - defaults/osx-arm64::biopython==1.78=py310h1a28f6b_0 -> python[version='2.7.*|3.5.*|3.6.*|>=2.7,<2.8.0a0|>=3.11,<3.12.0a0|>=3.8,<3.9.0a0|>=3.9,<3.10.0a0|>=3.7,<3.8.0a0|>=3.6,<3.7.0a0|>=3.5,<3.6.0a0|3.4.*']
#   - defaults/osx-arm64::brotlipy==0.7.0=py310h1a28f6b_1002 -> python[version='2.7.*|3.5.*|3.6.*|3.6.12|3.6.12|3.7.10|3.7.10|3.7.12|3.8.12|3.8.16|3.9.16|>=3.11,<3.12.0a0|>=3.8,<3.9.0a0|>=3.9,<3.10.0a0|>=3.7,<3.8.0a0|3.9.10|>=3.6,<3.7.0a0|3.7.9|3.6.9|3.6.9|3.6.9|>=2.7,<2.8.0a0|3.6.9|>=3.5,<3.6.0a0|3.4.*',build='0_73_pypy|2_73_pypy|5_73_pypy|5_73_pypy|1_73_pypy|0_73_pypy|0_73_pypy|4_73_pypy|3_73_pypy|1_73_pypy']
#   - defaults/osx-arm64::conda-content-trust==0.1.3=py310hca03da5_0 -> python[version='2.7.*|3.5.*|3.6.*|>=2.7,<2.8.0a0|>=3.11,<3.12.0a0|>=3.8,<3.9.0a0|>=3.9,<3.10.0a0|>=3.7,<3.8.0a0|>=3.6,<3.7.0a0|>=3.5,<3.6.0a0|3.4.*']
#   - defaults/osx-arm64::cryptography==38.0.1=py310h834c97f_0 -> python[version='3.6.12|3.6.12|3.7.10|3.7.10|3.7.12|3.8.12|3.8.16|3.9.16|>=3.11,<3.12.0a0|>=3.8,<3.9.0a0|>=3.9,<3.10.0a0|>=3.7,<3.8.0a0|3.9.10|>=3.6,<3.7.0a0|3.7.9|3.6.9|3.6.9|3.6.9|>=2.7,<2.8.0a0|3.6.9',build='0_73_pypy|2_73_pypy|5_73_pypy|5_73_pypy|1_73_pypy|0_73_pypy|0_73_pypy|4_73_pypy|3_73_pypy|1_73_pypy']
#   - defaults/osx-arm64::jinja2==3.1.2=py310hca03da5_0 -> python[version='>=3.11,<3.12.0a0|>=3.9,<3.10.0a0|>=3.8,<3.9.0a0|>=3.7,<3.8.0a0|>=3.6,<3.7.0a0']
#   - defaults/osx-arm64::pyqt==5.15.7=py310hc377ac9_0 -> python[version='>=3.11,<3.12.0a0|>=3.7,<3.8.0a0|>=3.8,<3.9.0a0|>=3.9,<3.10.0a0']
#   - defaults/osx-arm64::ruamel.yaml==0.17.21=py310h1a28f6b_0 -> python[version='>=3.11,<3.12.0a0|>=3.9,<3.10.0a0|>=3.8,<3.9.0a0|>=3.7,<3.8.0a0']
#   - defaults/osx-arm64::terminado==0.17.1=py310hca03da5_0 -> python[version='2.7.*|3.5.*|3.6.*|>=2.7,<2.8.0a0|>=3.5,<3.6.0a0|>=3.6,<3.7.0a0|>=3.7,<3.8.0a0|3.4.*|>=3.8,<3.9.0a0|>=3.11,<3.12.0a0|>=3.9,<3.10.0a0']
#   - defaults/osx-arm64::tinycss2==1.2.1=py310hca03da5_0 -> python[version='2.7.*|3.5.*|3.6.*|>=3.11,<3.12.0a0|>=3.9,<3.10.0a0|>=3.8,<3.9.0a0|>=3.5,<3.6.0a0|>=2.7,<2.8.0a0|>=3.7,<3.8.0a0|>=3.6,<3.7.0a0']
#   - defaults/osx-arm64::websocket-client==0.58.0=py310hca03da5_4 -> python[version='2.7.*|3.5.*|3.6.*|>=2.7,<2.8.0a0|>=3.6,<3.7.0a0|>=3.8,<3.9.0a0|>=3.7,<3.8.0a0|3.4.*|>=3.9,<3.10.0a0|>=3.5,<3.6.0a0']
#
# Your python: defaults/osx-arm64::python==3.10.8=hc0d8a6c_1
#
# If python is on the left-most side of the chain, that's the version you've asked for.
# When python appears to the right, that indicates that the thing on the left is somehow
# not available for the python version you are constrained to. Note that conda will not
# change your python version to a different minor version unless you explicitly specify
# that.
#
# The following specifications were found to be incompatible with a past
# explicit spec that is not an explicit spec in this operation (libdeflate):
#
#   - bedtools -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
#   - bedtools -> curl[version='>=7.64.1,<8.0a0'] -> krb5[version='>=1.16.1,<1.17.0a0|>=1.16.3,<1.17.0a0|>=1.16.4,<1.17.0a0|>=1.17.1,<1.18.0a0|>=1.19.1,<1.20.0a0|>=1.19.2,<1.20.0a0|>=1.19.3,<1.20.0a0|>=1.20.1,<1.21.0a0|>=1.18.2,<1.19.0a0']
#   - bedtools -> curl[version='>=7.64.1,<8.0a0'] -> openssl[version='>=1.1.1l,<1.1.2a|>=1.1.1n,<1.1.2a|>=1.1.1o,<1.1.2a|>=1.1.1q,<1.1.2a|>=1.1.1s,<1.1.2a|>=3.0.8,<4.0a0|>=3.1.0,<4.0a0|>=3.0.7,<4.0a0|>=3.0.5,<4.0a0|>=3.0.3,<4.0a0|>=3.0.2,<4.0a0|>=3.0.0,<4.0a0']
#   - bedtools -> curl[version='>=7.64.1,<8.0a0'] -> zstd[version='>=1.5.2,<1.6.0a0']
#   - bedtools -> libcxx[version='>=11.1.0|>=12.0.1|>=9.0.1|>=4.0.1']
#   - bedtools -> libdeflate[version='>=1.0,<1.1.0a0']
#   - bedtools -> libgcc -> libgfortran==3.0.1
#   - bedtools -> xz[version='>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0']
#   - bedtools -> zlib[version='1.2.11.*|>=1.2.11,<1.3.0a0|1.2.8.*']
#   - bioawk -> zlib[version='1.2.11.*|>=1.2.11,<1.3.0a0']
#   - samtools -> bzip2[version='1.0.*|>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
#   - samtools -> curl[version='>=7.59.0,<8.0a0'] -> zlib[version='1.2.*|1.2.11']
#   - samtools -> curl[version='>=7.64.0,<8.0a0'] -> krb5[version='1.14.*|>=1.14.6,<1.15.0a0|>=1.16.1,<1.17.0a0|>=1.16.3,<1.17.0a0|>=1.16.4,<1.17.0a0|>=1.17.1,<1.18.0a0|>=1.19.1,<1.20.0a0|>=1.19.2,<1.20.0a0|>=1.19.3,<1.20.0a0|>=1.20.1,<1.21.0a0|>=1.18.2,<1.19.0a0|>=1.16.2,<1.17.0a0']
#   - samtools -> curl[version='>=7.64.0,<8.0a0'] -> openssl[version='1.0.*|>=1.0.2o,<1.0.3a|>=1.1.1l,<1.1.2a|>=1.1.1n,<1.1.2a|>=1.1.1o,<1.1.2a|>=1.1.1q,<1.1.2a|>=1.1.1s,<1.1.2a|>=3.0.8,<4.0a0|>=3.1.0,<4.0a0|>=3.0.7,<4.0a0|>=3.0.5,<4.0a0|>=3.0.3,<4.0a0|>=3.0.2,<4.0a0|>=3.0.0,<4.0a0|>=1.0.2m,<1.0.3a']
#   - samtools -> curl[version='>=7.64.0,<8.0a0'] -> zstd[version='>=1.5.2,<1.6.0a0']
#   - samtools -> htslib[version='>=1.17,<1.18.0a0'] -> libdeflate[version='>=1.10,<1.19.0a0|>=1.13,<1.19.0a0|>=1.9,<1.19.0a0|>=1.7,<1.19.0a0|>=1.6,<1.19.0a0|>=1.3,<1.19.0a0']
#   - samtools -> htslib[version='>=1.17,<1.18.0a0'] -> xz[version='>=5.2.6,<5.3.0a0']
#   - samtools -> libdeflate[version='>=1.0,<1.1.0a0']
#   - samtools -> libgcc -> libgfortran==3.0.1
#   - samtools -> ncurses[version='5.9|5.9.*|>=5.9,<5.10.0a0|>=6.1,<6.2.0a0|>=6.2,<6.3.0a0|>=6.3,<7.0a0']
#   - samtools -> ncurses[version='>=6.2,<6.3.0a0'] -> libcxx[version='>=10.0.0|>=9.0.1|>=4.0.1']
#   - samtools -> openssl[version='>=1.0.2p,<1.0.3a|>=1.0.2r,<1.0.3a|>=1.1.1a,<1.1.2a']
#   - samtools -> openssl[version='>=1.1.1a,<1.1.2a'] -> ca-certificates
#   - samtools -> pkg-config -> libiconv[version='>=1.15,<2.0.0a0|>=1.16,<2.0.0a0|>=1.15,<2.0a0|>=1.16,<2.0a0']
#   - samtools -> xz[version='5.2.*|>=5.2.3,<5.3.0a0|>=5.2.4,<5.3.0a0|>=5.2.5,<5.3.0a0']
#   - samtools -> zlib[version='1.2.11.*|>=1.2.11,<1.3.0a0|>=1.2.12,<1.3.0a0|>=1.2.13,<1.3.0a0|1.2.8.*|1.2.8']
#
# The following specifications were found to be incompatible with each other:
#
# Output in format: Requested package -> Available versions
#
# Package sqlite conflicts for:
# defaults/noarch::pandocfilters==1.5.0=pyhd3eb1b0_0 -> python[version='!=3.0,!=3.1,!=3.2,!=3.3'] -> sqlite[version='3.13.*|3.20.*|>=3.24.0,<4.0a0|>=3.25.1,<4.0a0|>=3.25.2,<4.0a0|>=3.25.3,<4.0a0|>=3.26.0,<4.0a0|>=3.28.0,<4.0a0|>=3.30.1,<4.0a0|>=3.32.3,<4.0a0|>=3.33.0,<4.0a0|>=3.34.0,<4.0a0|>=3.35.5,<4.0a0|>=3.36.0,<4.0a0|>=3.37.0,<4.0a0|>=3.37.1,<4.0a0|>=3.38.5,<4.0a0|3.9.*|>=3.41.2,<4.0a0|>=3.41.1,<4.0a0|>=3.40.1,<4.0a0|>=3.40.0,<4.0a0|>=3.39.3,<4.0a0|>=3.37.2,<4.0a0|>=3.39.2,<4.0a0|>=3.38.3,<4.0a0|>=3.38.2,<4.0a0|>=3.35.4,<4.0a0|>=3.31.1,<4.0a0|>=3.30.0,<4.0a0|>=3.29.0,<4.0a0|>=3.27.2,<4.0a0|>=3.23.1,<4.0a0|>=3.22.0,<4.0a0|>=3.20.1,<4.0a0']
# defaults/osx-arm64::traitlets==5.7.1=py310hca03da5_0 -> python[version='>=3.10,<3.11.0a0'] -> sqlite[version='>=3.36.0,<4.0a0|>=3.37.0,<4.0a0|>=3.37.1,<4.0a0|>=3.38.5,<4.0a0|>=3.41.2,<4.0a0|>=3.41.1,<4.0a0|>=3.40.1,<4.0a0|>=3.40.0,<4.0a0|>=3.39.3,<4.0a0|>=3.37.2,<4.0a0']
# defaults/noarch::six==1.16.0=pyhd3eb1b0_1 -> python -> sqlite[version='3.13.*|3.20.*|>=3.24.0,<4.0a0|>=3.25.1,<4.0a0|>=3.25.2,<4.0a0|>=3.25.3,<4.0a0|>=3.26.0,<4.0a0|>=3.28.0,<4.0a0|>=3.30.1,<4.0a0|>=3.32.3,<4.0a0|>=3.33.0,<4.0a0|>=3.34.0,<4.0a0|>=3.35.5,<4.0a0|>=3.36.0,<4.0a0|>=3.37.0,<4.0a0|>=3.37.1,<4.0a0|>=3.38.5,<4.0a0|3.9.*|>=3.41.2,<4.0a0|>=3.41.1,<4.0a0|>=3.40.1,<4.0a0|>=3.40.0,<4.0a0|>=3.39.3,<4.0a0|>=3.37.2,<4.0a0|>=3.39.2,<4.0a0|>=3.38.3,<4.0a0|>=3.38.2,<4.0a0|>=3.35.4,<4.0a0|>=3.31.1,<4.0a0|>=3.30.0,<4.0a0|>=3.29.0,<4.0a0|>=3.27.2,<4.0a0|>=3.23.1,<4.0a0|>=3.22.0,<4.0a0|>=3.20.1,<4.0a0']
# defaults/noarch::jupyterlab_pygments==0.1.2=py_0 -> python -> sqlite[version='3.13.*|3.20.*|>=3.24.0,<4.0a0|>=3.25.1,<4.0a0|>=3.25.2,<4.0a0|>=3.25.3,<4.0a0|>=3.26.0,<4.0a0|>=3.28.0,<4.0a0|>=3.30.1,<4.0a0|>=3.32.3,<4.0a0|>=3.33.0,<4.0a0|>=3.34.0,<4.0a0|>=3.35.5,<4.0a0|>=3.36.0,<4.0a0|>=3.37.0,<4.0a0|>=3.37.1,<4.0a0|>=3.38.5,<4.0a0|3.9.*|>=3.41.2,<4.0a0|>=3.41.1,<4.0a0|>=3.40.1,<4.0a0|>=3.40.0,<4.0a0|>=3.39.3,<4.0a0|>=3.37.2,<4.0a0|>=3.39.2,<4.0a0|>=3.38.3,<4.0a0|>=3.38.2,<4.0a0|>=3.35.4,<4.0a0|>=3.31.1,<4.0a0|>=3.30.0,<4.0a0|>=3.29.0,<4.0a0|>=3.27.2,<4.0a0|>=3.23.1,<4.0a0|>=3.22.0,<4.0a0|>=3.20.1,<4.0a0']
# defaults/osx-arm64::tqdm==4.64.1=py310hca03da5_0 -> python[version='>=3.10,<3.11.0a0'] -> sqlite[version='>=3.36.0,<4.0a0|>=3.37.0,<4.0a0|>=3.37.1,<4.0a0|>=3.38.5,<4.0a0|>=3.41.2,<4.0a0|>=3.41.1,<4.0a0|>=3.40.1,<4.0a0|>=3.40.0,<4.0a0|>=3.39.3,<4.0a0|>=3.37.2,<4.0a0']
# defaults/noarch::json5==0.9.6=pyhd3eb1b0_0 -> python -> sqlite[version='3.13.*|3.20.*|>=3.24.0,<4.0a0|>=3.25.1,<4.0a0|>=3.25.2,<4.0a0|>=3.25.3,<4.0a0|>=3.26.0,<4.0a0|>=3.28.0,<4.0a0|>=3.30.1,<4.0a0|>=3.32.3,<4.0a0|>=3.33.0,<4.0a0|>=3.34.0,<4.0a0|>=3.35.5,<4.0a0|>=3.36.0,<4.0a0|>=3.37.0,<4.0a0|>=3.37.1,<4.0a0|>=3.38.5,<4.0a0|3.9.*|>=3.41.2,<4.0a0|>=3.41.1,<4.0a0|>=3.40.1,<4.0a0|>=3.40.0,<4.0a0|>=3.39.3,<4.0a0|>=3.37.2,<4.0a0|>=3.39.2,<4.0a0|>=3.38.3,<4.0a0|>=3.38.2,<4.0a0|>=3.35.4,<4.0a0|>=3.31.1,<4.0a0|>=3.30.0,<4.0a0|>=3.29.0,<4.0a0|>=3.27.2,<4.0a0|>=3.23.1,<4.0a0|>=3.22.0,<4.0a0|>=3.20.1,<4.0a0']
# defaults/osx-arm64::jedi==0.18.1=py310hca03da5_1 -> python[version='>=3.10,<3.11.0a0'] -> sqlite[version='>=3.36.0,<4.0a0|>=3.37.0,<4.0a0|>=3.37.1,<4.0a0|>=3.38.5,<4.0a0|>=3.41.2,<4.0a0|>=3.41.1,<4.0a0|>=3.40.1,<4.0a0|>=3.40.0,<4.0a0|>=3.39.3,<4.0a0|>=3.37.2,<4.0a0']
# defaults/osx-arm64::pip==22.3.1=py310hca03da5_0 -> python[version='>=3.10,<3.11.0a0'] -> sqlite[version='>=3.36.0,<4.0a0|>=3.37.0,<4.0a0|>=3.37.1,<4.0a0|>=3.38.5,<4.0a0|>=3.41.2,<4.0a0|>=3.41.1,<4.0a0|>=3.40.1,<4.0a0|>=3.40.0,<4.0a0|>=3.39.3,<4.0a0|>=3.37.2,<4.0a0']
# defaults/osx-arm64::nbclassic==0.4.8=py310hca03da5_0 -> python[version='>=3.10,<3.11.0a0'] -> sqlite[version='>=3.36.0,<4.0a0|>=3.37.0,<4.0a0|>=3.37.1,<4.0a0|>=3.38.5,<4.0a0|>=3.41.2,<4.0a0|>=3.41.1,<4.0a0|>=3.40.1,<4.0a0|>=3.40.0,<4.0a0|>=3.39.3,<4.0a0|>=3.37.2,<4.0a0']
# defaults/noarch::executing==0.8.3=pyhd3eb1b0_0 -> python[version='>=2.7'] -> sqlite[version='3.13.*|3.20.*|>=3.24.0,<4.0a0|>=3.25.1,<4.0a0|>=3.25.2,<4.0a0|>=3.25.3,<4.0a0|>=3.26.0,<4.0a0|>=3.28.0,<4.0a0|>=3.30.1,<4.0a0|>=3.32.3,<4.0a0|>=3.33.0,<4.0a0|>=3.34.0,<4.0a0|>=3.35.5,<4.0a0|>=3.36.0,<4.0a0|>=3.37.0,<4.0a0|>=3.37.1,<4.0a0|>=3.38.5,<4.0a0|3.9.*|>=3.41.2,<4.0a0|>=3.41.1,<4.0a0|>=3.40.1,<4.0a0|>=3.40.0,<4.0a0|>=3.39.3,<4.0a0|>=3.37.2,<4.0a0|>=3.39.2,<4.0a0|>=3.38.3,<4.0a0|>=3.38.2,<4.0a0|>=3.35.4,<4.0a0|>=3.31.1,<4.0a0|>=3.30.0,<4.0a0|>=3.29.0,<4.0a0|>=3.27.2,<4.0a0|>=3.23.1,<4.0a0|>=3.22.0,<4.0a0|>=3.20.1,<4.0a0']
# defaults/osx-arm64::ruamel.yaml==0.17.21=py310h1a28f6b_0 -> python[version='>=3.10,<3.11.0a0'] -> sqlite[version='>=3.36.0,<4.0a0|>=3.37.0,<4.0a0|>=3.37.1,<4.0a0|>=3.38.5,<4.0a0|>=3.41.2,<4.0a0|>=3.41.1,<4.0a0|>=3.40.1,<4.0a0|>=3.40.0,<4.0a0|>=3.39.3,<4.0a0|>=3.37.2,<4.0a0']
# defaults/noarch::bleach==4.1.0=pyhd3eb1b0_0 -> python[version='>=3.6'] -> sqlite[version='3.13.*|3.20.*|>=3.24.0,<4.0a0|>=3.25.1,<4.0a0|>=3.25.2,<4.0a0|>=3.25.3,<4.0a0|>=3.26.0,<4.0a0|>=3.28.0,<4.0a0|>=3.30.1,<4.0a0|>=3.32.3,<4.0a0|>=3.33.0,<4.0a0|>=3.34.0,<4.0a0|>=3.35.5,<4.0a0|>=3.36.0,<4.0a0|>=3.37.0,<4.0a0|>=3.37.1,<4.0a0|>=3.38.5,<4.0a0|>=3.41.2,<4.0a0|>=3.41.1,<4.0a0|>=3.40.1,<4.0a0|>=3.40.0,<4.0a0|>=3.39.3,<4.0a0|>=3.37.2,<4.0a0|>=3.39.2,<4.0a0|>=3.38.3,<4.0a0|>=3.38.2,<4.0a0|>=3.35.4,<4.0a0|>=3.31.1,<4.0a0|>=3.30.0,<4.0a0|>=3.29.0,<4.0a0|>=3.27.2,<4.0a0|>=3.23.1,<4.0a0|>=3.22.0,<4.0a0|>=3.20.1,<4.0a0']
# defaults/osx-arm64::ipykernel==6.19.2=py310h33ce5c2_0 -> python[version='>=3.10,<3.11.0a0'] -> sqlite[version='>=3.36.0,<4.0a0|>=3.37.0,<4.0a0|>=3.37.1,<4.0a0|>=3.38.5,<4.0a0|>=3.41.2,<4.0a0|>=3.41.1,<4.0a0|>=3.40.1,<4.0a0|>=3.40.0,<4.0a0|>=3.39.3,<4.0a0|>=3.37.2,<4.0a0']
# defaults/noarch::pure_eval==0.2.2=pyhd3eb1b0_0 -> python[version='>=3.5'] -> sqlite[version='3.13.*|3.20.*|>=3.24.0,<4.0a0|>=3.25.1,<4.0a0|>=3.25.2,<4.0a0|>=3.25.3,<4.0a0|>=3.26.0,<4.0a0|>=3.28.0,<4.0a0|>=3.30.1,<4.0a0|>=3.32.3,<4.0a0|>=3.33.0,<4.0a0|>=3.34.0,<4.0a0|>=3.35.5,<4.0a0|>=3.36.0,<4.0a0|>=3.37.0,<4.0a0|>=3.37.1,<4.0a0|>=3.38.5,<4.0a0|3.9.*|>=3.41.2,<4.0a0|>=3.41.1,<4.0a0|>=3.40.1,<4.0a0|>=3.40.0,<4.0a0|>=3.39.3,<4.0a0|>=3.37.2,<4.0a0|>=3.39.2,<4.0a0|>=3.38.3,<4.0a0|>=3.38.2,<4.0a0|>=3.35.4,<4.0a0|>=3.31.1,<4.0a0|>=3.30.0,<4.0a0|>=3.29.0,<4.0a0|>=3.27.2,<4.0a0|>=3.23.1,<4.0a0|>=3.22.0,<4.0a0|>=3.20.1,<4.0a0']
# defaults/noarch::decorator==5.1.1=pyhd3eb1b0_0 -> python[version='>=3.5'] -> sqlite[version='3.13.*|3.20.*|>=3.24.0,<4.0a0|>=3.25.1,<4.0a0|>=3.25.2,<4.0a0|>=3.25.3,<4.0a0|>=3.26.0,<4.0a0|>=3.28.0,<4.0a0|>=3.30.1,<4.0a0|>=3.32.3,<4.0a0|>=3.33.0,<4.0a0|>=3.34.0,<4.0a0|>=3.35.5,<4.0a0|>=3.36.0,<4.0a0|>=3.37.0,<4.0a0|>=3.37.1,<4.0a0|>=3.38.5,<4.0a0|3.9.*|>=3.41.2,<4.0a0|>=3.41.1,<4.0a0|>=3.40.1,<4.0a0|>=3.40.0,<4.0a0|>=3.39.3,<4.0a0|>=3.37.2,<4.0a0|>=3.39.2,<4.0a0|>=3.38.3,<4.0a0|>=3.38.2,<4.0a0|>=3.35.4,<4.0a0|>=3.31.1,<4.0a0|>=3.30.0,<4.0a0|>=3.29.0,<4.0a0|>=3.27.2,<4.0a0|>=3.23.1,<4.0a0|>=3.22.0,<4.0a0|>=3.20.1,<4.0a0']
# defaults/noarch::pickleshare==0.7.5=pyhd3eb1b0_1003 -> python[version='>=3'] -> sqlite[version='3.13.*|3.20.*|>=3.24.0,<4.0a0|>=3.25.1,<4.0a0|>=3.25.2,<4.0a0|>=3.25.3,<4.0a0|>=3.26.0,<4.0a0|>=3.28.0,<4.0a0|>=3.30.1,<4.0a0|>=3.32.3,<4.0a0|>=3.33.0,<4.0a0|>=3.34.0,<4.0a0|>=3.35.5,<4.0a0|>=3.36.0,<4.0a0|>=3.37.0,<4.0a0|>=3.37.1,<4.0a0|>=3.38.5,<4.0a0|3.9.*|>=3.41.2,<4.0a0|>=3.41.1,<4.0a0|>=3.40.1,<4.0a0|>=3.40.0,<4.0a0|>=3.39.3,<4.0a0|>=3.37.2,<4.0a0|>=3.39.2,<4.0a0|>=3.38.3,<4.0a0|>=3.38.2,<4.0a0|>=3.35.4,<4.0a0|>=3.31.1,<4.0a0|>=3.30.0,<4.0a0|>=3.29.0,<4.0a0|>=3.27.2,<4.0a0|>=3.23.1,<4.0a0|>=3.22.0,<4.0a0|>=3.20.1,<4.0a0']
# defaults/osx-arm64::argon2-cffi-bindings==21.2.0=py310h1a28f6b_0 -> python[version='>=3.10,<3.11.0a0'] -> sqlite[version='>=3.36.0,<4.0a0|>=3.37.0,<4.0a0|>=3.37.1,<4.0a0|>=3.38.5,<4.0a0|>=3.41.2,<4.0a0|>=3.41.1,<4.0a0|>=3.40.1,<4.0a0|>=3.40.0,<4.0a0|>=3.39.3,<4.0a0|>=3.37.2,<4.0a0']
# defaults/osx-arm64::nest-asyncio==1.5.6=py310hca03da5_0 -> python[version='>=3.10,<3.11.0a0'] -> sqlite[version='>=3.36.0,<4.0a0|>=3.37.0,<4.0a0|>=3.37.1,<4.0a0|>=3.38.5,<4.0a0|>=3.41.2,<4.0a0|>=3.41.1,<4.0a0|>=3.40.1,<4.0a0|>=3.40.0,<4.0a0|>=3.39.3,<4.0a0|>=3.37.2,<4.0a0']
# certifi -> python[version='>=3.7'] -> sqlite[version='3.13.*|3.20.*|>=3.24.0,<4.0a0|>=3.25.1,<4.0a0|>=3.25.2,<4.0a0|>=3.25.3,<4.0a0|>=3.26.0,<4.0a0|>=3.28.0,<4.0a0|>=3.30.1,<4.0a0|>=3.32.3,<4.0a0|>=3.33.0,<4.0a0|>=3.34.0,<4.0a0|>=3.35.5,<4.0a0|>=3.36.0,<4.0a0|>=3.37.0,<4.0a0|>=3.37.1,<4.0a0|>=3.38.5,<4.0a0|>=3.41.2,<4.0a0|>=3.41.1,<4.0a0|>=3.40.1,<4.0a0|>=3.40.0,<4.0a0|>=3.39.3,<4.0a0|>=3.37.2,<4.0a0|>=3.39.2,<4.0a0|>=3.38.3,<4.0a0|>=3.38.2,<4.0a0|>=3.35.4,<4.0a0|>=3.31.1,<4.0a0|>=3.30.0,<4.0a0|>=3.29.0,<4.0a0|>=3.27.2,<4.0a0|>=3.39.1,<4.0a0|>=3.23.1,<4.0a0|>=3.22.0,<4.0a0|>=3.20.1,<4.0a0|3.9.*']
# defaults/osx-arm64::python==3.10.8=hc0d8a6c_1 -> sqlite[version='>=3.40.0,<4.0a0']
# defaults/osx-arm64::jupyter_server==1.23.4=py310hca03da5_0 -> python[version='>=3.10,<3.11.0a0'] -> sqlite[version='>=3.36.0,<4.0a0|>=3.37.0,<4.0a0|>=3.37.1,<4.0a0|>=3.38.5,<4.0a0|>=3.41.2,<4.0a0|>=3.41.1,<4.0a0|>=3.40.1,<4.0a0|>=3.40.0,<4.0a0|>=3.39.3,<4.0a0|>=3.37.2,<4.0a0']
# defaults/noarch::pexpect==4.8.0=pyhd3eb1b0_3 -> python -> sqlite[version='3.13.*|3.20.*|>=3.24.0,<4.0a0|>=3.25.1,<4.0a0|>=3.25.2,<4.0a0|>=3.25.3,<4.0a0|>=3.26.0,<4.0a0|>=3.28.0,<4.0a0|>=3.30.1,<4.0a0|>=3.32.3,<4.0a0|>=3.33.0,<4.0a0|>=3.34.0,<4.0a0|>=3.35.5,<4.0a0|>=3.36.0,<4.0a0|>=3.37.0,<4.0a0|>=3.37.1,<4.0a0|>=3.38.5,<4.0a0|3.9.*|>=3.41.2,<4.0a0|>=3.41.1,<4.0a0|>=3.40.1,<4.0a0|>=3.40.0,<4.0a0|>=3.39.3,<4.0a0|>=3.37.2,<4.0a0|>=3.39.2,<4.0a0|>=3.38.3,<4.0a0|>=3.38.2,<4.0a0|>=3.35.4,<4.0a0|>=3.31.1,<4.0a0|>=3.30.0,<4.0a0|>=3.29.0,<4.0a0|>=3.27.2,<4.0a0|>=3.23.1,<4.0a0|>=3.22.0,<4.0a0|>=3.20.1,<4.0a0']
# defaults/osx-arm64::python-fastjsonschema==2.16.2=py310hca03da5_0 -> python[version='>=3.10,<3.11.0a0'] -> sqlite[version='>=3.36.0,<4.0a0|>=3.37.0,<4.0a0|>=3.37.1,<4.0a0|>=3.38.5,<4.0a0|>=3.41.2,<4.0a0|>=3.41.1,<4.0a0|>=3.40.1,<4.0a0|>=3.40.0,<4.0a0|>=3.39.3,<4.0a0|>=3.37.2,<4.0a0']
# defaults/osx-arm64::tinycss2==1.2.1=py310hca03da5_0 -> python[version='>=3.10,<3.11.0a0'] -> sqlite[version='>=3.36.0,<4.0a0|>=3.37.0,<4.0a0|>=3.37.1,<4.0a0|>=3.38.5,<4.0a0|>=3.41.2,<4.0a0|>=3.41.1,<4.0a0|>=3.40.1,<4.0a0|>=3.40.0,<4.0a0|>=3.39.3,<4.0a0|>=3.37.2,<4.0a0']
# defaults/osx-arm64::numpy==1.23.5=py310hb93e574_0 -> python[version='>=3.10,<3.11.0a0'] -> sqlite[version='>=3.36.0,<4.0a0|>=3.37.0,<4.0a0|>=3.37.1,<4.0a0|>=3.38.5,<4.0a0|>=3.41.2,<4.0a0|>=3.41.1,<4.0a0|>=3.40.1,<4.0a0|>=3.40.0,<4.0a0|>=3.39.3,<4.0a0|>=3.37.2,<4.0a0']
# defaults/osx-arm64::nbformat==5.7.0=py310hca03da5_0 -> python[version='>=3.10,<3.11.0a0'] -> sqlite[version='>=3.36.0,<4.0a0|>=3.37.0,<4.0a0|>=3.37.1,<4.0a0|>=3.38.5,<4.0a0|>=3.41.2,<4.0a0|>=3.41.1,<4.0a0|>=3.40.1,<4.0a0|>=3.40.0,<4.0a0|>=3.39.3,<4.0a0|>=3.37.2,<4.0a0']
# defaults/osx-arm64::terminado==0.17.1=py310hca03da5_0 -> python[version='>=3.10,<3.11.0a0'] -> sqlite[version='>=3.36.0,<4.0a0|>=3.37.0,<4.0a0|>=3.37.1,<4.0a0|>=3.38.5,<4.0a0|>=3.41.2,<4.0a0|>=3.41.1,<4.0a0|>=3.40.1,<4.0a0|>=3.40.0,<4.0a0|>=3.39.3,<4.0a0|>=3.37.2,<4.0a0']
# defaults/osx-arm64::ruamel.yaml.clib==0.2.6=py310h1a28f6b_1 -> python[version='>=3.10,<3.11.0a0'] -> sqlite[version='>=3.36.0,<4.0a0|>=3.37.0,<4.0a0|>=3.37.1,<4.0a0|>=3.38.5,<4.0a0|>=3.41.2,<4.0a0|>=3.41.1,<4.0a0|>=3.40.1,<4.0a0|>=3.40.0,<4.0a0|>=3.39.3,<4.0a0|>=3.37.2,<4.0a0']
# defaults/osx-arm64::requests==2.28.1=py310hca03da5_0 -> python[version='>=3.10,<3.11.0a0'] -> sqlite[version='>=3.36.0,<4.0a0|>=3.37.0,<4.0a0|>=3.37.1,<4.0a0|>=3.38.5,<4.0a0|>=3.41.2,<4.0a0|>=3.41.1,<4.0a0|>=3.40.1,<4.0a0|>=3.40.0,<4.0a0|>=3.39.3,<4.0a0|>=3.37.2,<4.0a0']
# defaults/osx-arm64::platformdirs==2.5.2=py310hca03da5_0 -> python[version='>=3.10,<3.11.0a0'] -> sqlite[version='>=3.36.0,<4.0a0|>=3.37.0,<4.0a0|>=3.37.1,<4.0a0|>=3.38.5,<4.0a0|>=3.41.2,<4.0a0|>=3.41.1,<4.0a0|>=3.40.1,<4.0a0|>=3.40.0,<4.0a0|>=3.39.3,<4.0a0|>=3.37.2,<4.0a0']
# defaults/osx-arm64::nss==3.74=h142855e_0 -> sqlite[version='>=3.37.0,<4.0a0']
# defaults/osx-arm64::pyzmq==23.2.0=py310hc377ac9_0 -> python[version='>=3.10,<3.11.0a0'] -> sqlite[version='>=3.36.0,<4.0a0|>=3.37.0,<4.0a0|>=3.37.1,<4.0a0|>=3.38.5,<4.0a0|>=3.41.2,<4.0a0|>=3.41.1,<4.0a0|>=3.40.1,<4.0a0|>=3.40.0,<4.0a0|>=3.39.3,<4.0a0|>=3.37.2,<4.0a0']
# defaults/osx-arm64::conda-package-handling==1.9.0=py310h1a28f6b_1 -> python[version='>=3.10,<3.11.0a0'] -> sqlite[version='>=3.36.0,<4.0a0|>=3.37.0,<4.0a0|>=3.37.1,<4.0a0|>=3.38.5,<4.0a0|>=3.41.2,<4.0a0|>=3.41.1,<4.0a0|>=3.40.1,<4.0a0|>=3.40.0,<4.0a0|>=3.39.3,<4.0a0|>=3.37.2,<4.0a0']
# defaults/osx-arm64::setuptools==65.5.0=py310hca03da5_0 -> python[version='>=3.10,<3.11.0a0'] -> sqlite[version='>=3.36.0,<4.0a0|>=3.37.0,<4.0a0|>=3.37.1,<4.0a0|>=3.38.5,<4.0a0|>=3.41.2,<4.0a0|>=3.41.1,<4.0a0|>=3.40.1,<4.0a0|>=3.40.0,<4.0a0|>=3.39.3,<4.0a0|>=3.37.2,<4.0a0']
# defaults/osx-arm64::cryptography==38.0.1=py310h834c97f_0 -> python[version='>=3.10,<3.11.0a0'] -> sqlite[version='>=3.36.0,<4.0a0|>=3.37.0,<4.0a0|>=3.37.1,<4.0a0|>=3.38.5,<4.0a0|>=3.41.2,<4.0a0|>=3.41.1,<4.0a0|>=3.40.1,<4.0a0|>=3.40.0,<4.0a0|>=3.39.3,<4.0a0|>=3.37.2,<4.0a0']
# defaults/osx-arm64::jupyterlab==3.5.3=py310hca03da5_0 -> python[version='>=3.10,<3.11.0a0'] -> sqlite[version='>=3.36.0,<4.0a0|>=3.37.0,<4.0a0|>=3.37.1,<4.0a0|>=3.38.5,<4.0a0|>=3.41.2,<4.0a0|>=3.41.1,<4.0a0|>=3.40.1,<4.0a0|>=3.40.0,<4.0a0|>=3.39.3,<4.0a0|>=3.37.2,<4.0a0']
# defaults/osx-arm64::jupyter==1.0.0=py310hca03da5_8 -> python[version='>=3.10,<3.11.0a0'] -> sqlite[version='>=3.36.0,<4.0a0|>=3.37.0,<4.0a0|>=3.37.1,<4.0a0|>=3.38.5,<4.0a0|>=3.41.2,<4.0a0|>=3.41.1,<4.0a0|>=3.40.1,<4.0a0|>=3.40.0,<4.0a0|>=3.39.3,<4.0a0|>=3.37.2,<4.0a0']
# defaults/osx-arm64::tomli==2.0.1=py310hca03da5_0 -> python[version='>=3.10,<3.11.0a0'] -> sqlite[version='>=3.36.0,<4.0a0|>=3.37.0,<4.0a0|>=3.37.1,<4.0a0|>=3.38.5,<4.0a0|>=3.41.2,<4.0a0|>=3.41.1,<4.0a0|>=3.40.1,<4.0a0|>=3.40.0,<4.0a0|>=3.39.3,<4.0a0|>=3.37.2,<4.0a0']
# defaults/noarch::jupyterlab_widgets==1.0.0=pyhd3eb1b0_1 -> python[version='>=3.6'] -> sqlite[version='3.13.*|3.20.*|>=3.24.0,<4.0a0|>=3.25.1,<4.0a0|>=3.25.2,<4.0a0|>=3.25.3,<4.0a0|>=3.26.0,<4.0a0|>=3.28.0,<4.0a0|>=3.30.1,<4.0a0|>=3.32.3,<4.0a0|>=3.33.0,<4.0a0|>=3.34.0,<4.0a0|>=3.35.5,<4.0a0|>=3.36.0,<4.0a0|>=3.37.0,<4.0a0|>=3.37.1,<4.0a0|>=3.38.5,<4.0a0|>=3.41.2,<4.0a0|>=3.41.1,<4.0a0|>=3.40.1,<4.0a0|>=3.40.0,<4.0a0|>=3.39.3,<4.0a0|>=3.37.2,<4.0a0|>=3.39.2,<4.0a0|>=3.38.3,<4.0a0|>=3.38.2,<4.0a0|>=3.35.4,<4.0a0|>=3.31.1,<4.0a0|>=3.30.0,<4.0a0|>=3.29.0,<4.0a0|>=3.27.2,<4.0a0|>=3.23.1,<4.0a0|>=3.22.0,<4.0a0|>=3.20.1,<4.0a0']
# defaults/osx-arm64::debugpy==1.5.1=py310hc377ac9_0 -> python[version='>=3.10,<3.11.0a0'] -> sqlite[version='>=3.36.0,<4.0a0|>=3.37.0,<4.0a0|>=3.37.1,<4.0a0|>=3.38.5,<4.0a0|>=3.41.2,<4.0a0|>=3.41.1,<4.0a0|>=3.40.1,<4.0a0|>=3.40.0,<4.0a0|>=3.39.3,<4.0a0|>=3.37.2,<4.0a0']
# defaults/osx-arm64::numpy-base==1.23.5=py310haf87e8b_0 -> python[version='>=3.10,<3.11.0a0'] -> sqlite[version='>=3.36.0,<4.0a0|>=3.37.0,<4.0a0|>=3.37.1,<4.0a0|>=3.38.5,<4.0a0|>=3.41.2,<4.0a0|>=3.41.1,<4.0a0|>=3.40.1,<4.0a0|>=3.40.0,<4.0a0|>=3.39.3,<4.0a0|>=3.37.2,<4.0a0']
# defaults/osx-arm64::pysocks==1.7.1=py310hca03da5_0 -> python[version='>=3.10,<3.11.0a0'] -> sqlite[version='>=3.36.0,<4.0a0|>=3.37.0,<4.0a0|>=3.37.1,<4.0a0|>=3.38.5,<4.0a0|>=3.41.2,<4.0a0|>=3.41.1,<4.0a0|>=3.40.1,<4.0a0|>=3.40.0,<4.0a0|>=3.39.3,<4.0a0|>=3.37.2,<4.0a0']
# defaults/noarch::defusedxml==0.7.1=pyhd3eb1b0_0 -> python -> sqlite[version='3.13.*|3.20.*|>=3.24.0,<4.0a0|>=3.25.1,<4.0a0|>=3.25.2,<4.0a0|>=3.25.3,<4.0a0|>=3.26.0,<4.0a0|>=3.28.0,<4.0a0|>=3.30.1,<4.0a0|>=3.32.3,<4.0a0|>=3.33.0,<4.0a0|>=3.34.0,<4.0a0|>=3.35.5,<4.0a0|>=3.36.0,<4.0a0|>=3.37.0,<4.0a0|>=3.37.1,<4.0a0|>=3.38.5,<4.0a0|3.9.*|>=3.41.2,<4.0a0|>=3.41.1,<4.0a0|>=3.40.1,<4.0a0|>=3.40.0,<4.0a0|>=3.39.3,<4.0a0|>=3.37.2,<4.0a0|>=3.39.2,<4.0a0|>=3.38.3,<4.0a0|>=3.38.2,<4.0a0|>=3.35.4,<4.0a0|>=3.31.1,<4.0a0|>=3.30.0,<4.0a0|>=3.29.0,<4.0a0|>=3.27.2,<4.0a0|>=3.23.1,<4.0a0|>=3.22.0,<4.0a0|>=3.20.1,<4.0a0']
# defaults/osx-arm64::conda-content-trust==0.1.3=py310hca03da5_0 -> python[version='>=3.10,<3.11.0a0'] -> sqlite[version='>=3.36.0,<4.0a0|>=3.37.0,<4.0a0|>=3.37.1,<4.0a0|>=3.38.5,<4.0a0|>=3.41.2,<4.0a0|>=3.41.1,<4.0a0|>=3.40.1,<4.0a0|>=3.40.0,<4.0a0|>=3.39.3,<4.0a0|>=3.37.2,<4.0a0']
# defaults/noarch::pycparser==2.21=pyhd3eb1b0_0 -> python[version='>=3.6'] -> sqlite[version='3.13.*|3.20.*|>=3.24.0,<4.0a0|>=3.25.1,<4.0a0|>=3.25.2,<4.0a0|>=3.25.3,<4.0a0|>=3.26.0,<4.0a0|>=3.28.0,<4.0a0|>=3.30.1,<4.0a0|>=3.32.3,<4.0a0|>=3.33.0,<4.0a0|>=3.34.0,<4.0a0|>=3.35.5,<4.0a0|>=3.36.0,<4.0a0|>=3.37.0,<4.0a0|>=3.37.1,<4.0a0|>=3.38.5,<4.0a0|>=3.41.2,<4.0a0|>=3.41.1,<4.0a0|>=3.40.1,<4.0a0|>=3.40.0,<4.0a0|>=3.39.3,<4.0a0|>=3.37.2,<4.0a0|>=3.39.2,<4.0a0|>=3.38.3,<4.0a0|>=3.38.2,<4.0a0|>=3.35.4,<4.0a0|>=3.31.1,<4.0a0|>=3.30.0,<4.0a0|>=3.29.0,<4.0a0|>=3.27.2,<4.0a0|>=3.23.1,<4.0a0|>=3.22.0,<4.0a0|>=3.20.1,<4.0a0']
# defaults/osx-arm64::websocket-client==0.58.0=py310hca03da5_4 -> python[version='>=3.10,<3.11.0a0'] -> sqlite[version='>=3.36.0,<4.0a0|>=3.37.0,<4.0a0|>=3.37.1,<4.0a0|>=3.38.5,<4.0a0|>=3.41.2,<4.0a0|>=3.41.1,<4.0a0|>=3.40.1,<4.0a0|>=3.40.0,<4.0a0|>=3.39.3,<4.0a0|>=3.37.2,<4.0a0']
# defaults/osx-arm64::pluggy==1.0.0=py310hca03da5_1 -> python[version='>=3.10,<3.11.0a0'] -> sqlite[version='>=3.36.0,<4.0a0|>=3.37.0,<4.0a0|>=3.37.1,<4.0a0|>=3.38.5,<4.0a0|>=3.41.2,<4.0a0|>=3.41.1,<4.0a0|>=3.40.1,<4.0a0|>=3.40.0,<4.0a0|>=3.39.3,<4.0a0|>=3.37.2,<4.0a0']
# defaults/osx-arm64::jupyter_console==6.4.4=py310hca03da5_0 -> python[version='>=3.10,<3.11.0a0'] -> sqlite[version='>=3.36.0,<4.0a0|>=3.37.0,<4.0a0|>=3.37.1,<4.0a0|>=3.38.5,<4.0a0|>=3.41.2,<4.0a0|>=3.41.1,<4.0a0|>=3.40.1,<4.0a0|>=3.40.0,<4.0a0|>=3.39.3,<4.0a0|>=3.37.2,<4.0a0']
# defaults/osx-arm64::tornado==6.2=py310h1a28f6b_0 -> python[version='>=3.10,<3.11.0a0'] -> sqlite[version='>=3.36.0,<4.0a0|>=3.37.0,<4.0a0|>=3.37.1,<4.0a0|>=3.38.5,<4.0a0|>=3.41.2,<4.0a0|>=3.41.1,<4.0a0|>=3.40.1,<4.0a0|>=3.40.0,<4.0a0|>=3.39.3,<4.0a0|>=3.37.2,<4.0a0']
# defaults/noarch::charset-normalizer==2.0.4=pyhd3eb1b0_0 -> python[version='>=3.5'] -> sqlite[version='3.13.*|3.20.*|>=3.24.0,<4.0a0|>=3.25.1,<4.0a0|>=3.25.2,<4.0a0|>=3.25.3,<4.0a0|>=3.26.0,<4.0a0|>=3.28.0,<4.0a0|>=3.30.1,<4.0a0|>=3.32.3,<4.0a0|>=3.33.0,<4.0a0|>=3.34.0,<4.0a0|>=3.35.5,<4.0a0|>=3.36.0,<4.0a0|>=3.37.0,<4.0a0|>=3.37.1,<4.0a0|>=3.38.5,<4.0a0|3.9.*|>=3.41.2,<4.0a0|>=3.41.1,<4.0a0|>=3.40.1,<4.0a0|>=3.40.0,<4.0a0|>=3.39.3,<4.0a0|>=3.37.2,<4.0a0|>=3.39.2,<4.0a0|>=3.38.3,<4.0a0|>=3.38.2,<4.0a0|>=3.35.4,<4.0a0|>=3.31.1,<4.0a0|>=3.30.0,<4.0a0|>=3.29.0,<4.0a0|>=3.27.2,<4.0a0|>=3.23.1,<4.0a0|>=3.22.0,<4.0a0|>=3.20.1,<4.0a0']
# defaults/osx-arm64::qtconsole==5.4.0=py310hca03da5_0 -> python[version='>=3.10,<3.11.0a0'] -> sqlite[version='>=3.36.0,<4.0a0|>=3.37.0,<4.0a0|>=3.37.1,<4.0a0|>=3.38.5,<4.0a0|>=3.41.2,<4.0a0|>=3.41.1,<4.0a0|>=3.40.1,<4.0a0|>=3.40.0,<4.0a0|>=3.39.3,<4.0a0|>=3.37.2,<4.0a0']
# defaults/osx-arm64::qt-main==5.15.2=ha2d02b5_7 -> sqlite[version='>=3.39.2,<4.0a0']
# defaults/osx-arm64::sniffio==1.2.0=py310hca03da5_1 -> python[version='>=3.10,<3.11.0a0'] -> sqlite[version='>=3.36.0,<4.0a0|>=3.37.0,<4.0a0|>=3.37.1,<4.0a0|>=3.38.5,<4.0a0|>=3.41.2,<4.0a0|>=3.41.1,<4.0a0|>=3.40.1,<4.0a0|>=3.40.0,<4.0a0|>=3.39.3,<4.0a0|>=3.37.2,<4.0a0']
# defaults/osx-arm64::psutil==5.9.0=py310h1a28f6b_0 -> python[version='>=3.10,<3.11.0a0'] -> sqlite[version='>=3.36.0,<4.0a0|>=3.37.0,<4.0a0|>=3.37.1,<4.0a0|>=3.38.5,<4.0a0|>=3.41.2,<4.0a0|>=3.41.1,<4.0a0|>=3.40.1,<4.0a0|>=3.40.0,<4.0a0|>=3.39.3,<4.0a0|>=3.37.2,<4.0a0']
# defaults/noarch::pyopenssl==22.0.0=pyhd3eb1b0_0 -> python[version='>=3.6'] -> sqlite[version='3.13.*|3.20.*|>=3.24.0,<4.0a0|>=3.25.1,<4.0a0|>=3.25.2,<4.0a0|>=3.25.3,<4.0a0|>=3.26.0,<4.0a0|>=3.28.0,<4.0a0|>=3.30.1,<4.0a0|>=3.32.3,<4.0a0|>=3.33.0,<4.0a0|>=3.34.0,<4.0a0|>=3.35.5,<4.0a0|>=3.36.0,<4.0a0|>=3.37.0,<4.0a0|>=3.37.1,<4.0a0|>=3.38.5,<4.0a0|>=3.41.2,<4.0a0|>=3.41.1,<4.0a0|>=3.40.1,<4.0a0|>=3.40.0,<4.0a0|>=3.39.3,<4.0a0|>=3.37.2,<4.0a0|>=3.39.2,<4.0a0|>=3.38.3,<4.0a0|>=3.38.2,<4.0a0|>=3.35.4,<4.0a0|>=3.31.1,<4.0a0|>=3.30.0,<4.0a0|>=3.29.0,<4.0a0|>=3.27.2,<4.0a0|>=3.23.1,<4.0a0|>=3.22.0,<4.0a0|>=3.20.1,<4.0a0']
# defaults/osx-arm64::pyqt==5.15.7=py310hc377ac9_0 -> python[version='>=3.10,<3.11.0a0'] -> sqlite[version='>=3.33.0,<4.0a0|>=3.34.0,<4.0a0|>=3.36.0,<4.0a0|>=3.37.0,<4.0a0|>=3.37.1,<4.0a0|>=3.38.5,<4.0a0|>=3.41.2,<4.0a0|>=3.41.1,<4.0a0|>=3.40.1,<4.0a0|>=3.40.0,<4.0a0|>=3.39.3,<4.0a0|>=3.37.2,<4.0a0|>=3.38.2,<4.0a0|>=3.39.2,<4.0a0|>=3.38.3,<4.0a0']
# defaults/noarch::send2trash==1.8.0=pyhd3eb1b0_1 -> python -> sqlite[version='3.13.*|3.20.*|>=3.24.0,<4.0a0|>=3.25.1,<4.0a0|>=3.25.2,<4.0a0|>=3.25.3,<4.0a0|>=3.26.0,<4.0a0|>=3.28.0,<4.0a0|>=3.30.1,<4.0a0|>=3.32.3,<4.0a0|>=3.33.0,<4.0a0|>=3.34.0,<4.0a0|>=3.35.5,<4.0a0|>=3.36.0,<4.0a0|>=3.37.0,<4.0a0|>=3.37.1,<4.0a0|>=3.38.5,<4.0a0|3.9.*|>=3.41.2,<4.0a0|>=3.41.1,<4.0a0|>=3.40.1,<4.0a0|>=3.40.0,<4.0a0|>=3.39.3,<4.0a0|>=3.37.2,<4.0a0|>=3.39.2,<4.0a0|>=3.38.3,<4.0a0|>=3.38.2,<4.0a0|>=3.35.4,<4.0a0|>=3.31.1,<4.0a0|>=3.30.0,<4.0a0|>=3.29.0,<4.0a0|>=3.27.2,<4.0a0|>=3.23.1,<4.0a0|>=3.22.0,<4.0a0|>=3.20.1,<4.0a0']
# defaults/osx-arm64::qt-webengine==5.15.9=h2903aaf_4 -> qt-main[version='>=5.15,<6.0a0'] -> sqlite[version='>=3.37.0,<4.0a0|>=3.38.2,<4.0a0|>=3.38.5,<4.0a0|>=3.41.1,<4.0a0|>=3.39.2,<4.0a0']
# defaults/osx-arm64::nbclient==0.5.13=py310hca03da5_0 -> python[version='>=3.10,<3.11.0a0'] -> sqlite[version='>=3.36.0,<4.0a0|>=3.37.0,<4.0a0|>=3.37.1,<4.0a0|>=3.38.5,<4.0a0|>=3.41.2,<4.0a0|>=3.41.1,<4.0a0|>=3.40.1,<4.0a0|>=3.40.0,<4.0a0|>=3.39.3,<4.0a0|>=3.37.2,<4.0a0']
# defaults/osx-arm64::soupsieve==2.3.2.post1=py310hca03da5_0 -> python[version='>=3.10,<3.11.0a0'] -> sqlite[version='>=3.36.0,<4.0a0|>=3.37.0,<4.0a0|>=3.37.1,<4.0a0|>=3.38.5,<4.0a0|>=3.41.2,<4.0a0|>=3.41.1,<4.0a0|>=3.40.1,<4.0a0|>=3.40.0,<4.0a0|>=3.39.3,<4.0a0|>=3.37.2,<4.0a0']
# defaults/noarch::asttokens==2.0.5=pyhd3eb1b0_0 -> python[version='>=3.5'] -> sqlite[version='3.13.*|3.20.*|>=3.24.0,<4.0a0|>=3.25.1,<4.0a0|>=3.25.2,<4.0a0|>=3.25.3,<4.0a0|>=3.26.0,<4.0a0|>=3.28.0,<4.0a0|>=3.30.1,<4.0a0|>=3.32.3,<4.0a0|>=3.33.0,<4.0a0|>=3.34.0,<4.0a0|>=3.35.5,<4.0a0|>=3.36.0,<4.0a0|>=3.37.0,<4.0a0|>=3.37.1,<4.0a0|>=3.38.5,<4.0a0|3.9.*|>=3.41.2,<4.0a0|>=3.41.1,<4.0a0|>=3.40.1,<4.0a0|>=3.40.0,<4.0a0|>=3.39.3,<4.0a0|>=3.37.2,<4.0a0|>=3.39.2,<4.0a0|>=3.38.3,<4.0a0|>=3.38.2,<4.0a0|>=3.35.4,<4.0a0|>=3.31.1,<4.0a0|>=3.30.0,<4.0a0|>=3.29.0,<4.0a0|>=3.27.2,<4.0a0|>=3.23.1,<4.0a0|>=3.22.0,<4.0a0|>=3.20.1,<4.0a0']
# defaults/osx-arm64::urllib3==1.26.13=py310hca03da5_0 -> python[version='>=3.10,<3.11.0a0'] -> sqlite[version='>=3.36.0,<4.0a0|>=3.37.0,<4.0a0|>=3.37.1,<4.0a0|>=3.38.5,<4.0a0|>=3.41.2,<4.0a0|>=3.41.1,<4.0a0|>=3.40.1,<4.0a0|>=3.40.0,<4.0a0|>=3.39.3,<4.0a0|>=3.37.2,<4.0a0']
# defaults/noarch::wcwidth==0.2.5=pyhd3eb1b0_0 -> python -> sqlite[version='3.13.*|3.20.*|>=3.24.0,<4.0a0|>=3.25.1,<4.0a0|>=3.25.2,<4.0a0|>=3.25.3,<4.0a0|>=3.26.0,<4.0a0|>=3.28.0,<4.0a0|>=3.30.1,<4.0a0|>=3.32.3,<4.0a0|>=3.33.0,<4.0a0|>=3.34.0,<4.0a0|>=3.35.5,<4.0a0|>=3.36.0,<4.0a0|>=3.37.0,<4.0a0|>=3.37.1,<4.0a0|>=3.38.5,<4.0a0|3.9.*|>=3.41.2,<4.0a0|>=3.41.1,<4.0a0|>=3.40.1,<4.0a0|>=3.40.0,<4.0a0|>=3.39.3,<4.0a0|>=3.37.2,<4.0a0|>=3.39.2,<4.0a0|>=3.38.3,<4.0a0|>=3.38.2,<4.0a0|>=3.35.4,<4.0a0|>=3.31.1,<4.0a0|>=3.30.0,<4.0a0|>=3.29.0,<4.0a0|>=3.27.2,<4.0a0|>=3.23.1,<4.0a0|>=3.22.0,<4.0a0|>=3.20.1,<4.0a0']
# defaults/osx-arm64::pyrsistent==0.18.0=py310h1a28f6b_0 -> python[version='>=3.10,<3.11.0a0'] -> sqlite[version='>=3.36.0,<4.0a0|>=3.37.0,<4.0a0|>=3.37.1,<4.0a0|>=3.38.5,<4.0a0|>=3.41.2,<4.0a0|>=3.41.1,<4.0a0|>=3.40.1,<4.0a0|>=3.40.0,<4.0a0|>=3.39.3,<4.0a0|>=3.37.2,<4.0a0']
# defaults/osx-arm64::pycosat==0.6.4=py310h1a28f6b_0 -> python[version='>=3.10,<3.11.0a0'] -> sqlite[version='>=3.36.0,<4.0a0|>=3.37.0,<4.0a0|>=3.37.1,<4.0a0|>=3.38.5,<4.0a0|>=3.41.2,<4.0a0|>=3.41.1,<4.0a0|>=3.40.1,<4.0a0|>=3.40.0,<4.0a0|>=3.39.3,<4.0a0|>=3.37.2,<4.0a0']
# defaults/osx-arm64::pytz==2022.7=py310hca03da5_0 -> python[version='>=3.10,<3.11.0a0'] -> sqlite[version='>=3.36.0,<4.0a0|>=3.37.0,<4.0a0|>=3.37.1,<4.0a0|>=3.38.5,<4.0a0|>=3.41.2,<4.0a0|>=3.41.1,<4.0a0|>=3.40.1,<4.0a0|>=3.40.0,<4.0a0|>=3.39.3,<4.0a0|>=3.37.2,<4.0a0']
# defaults/osx-arm64::toolz==0.12.0=py310hca03da5_0 -> python[version='>=3.10,<3.11.0a0'] -> sqlite[version='>=3.36.0,<4.0a0|>=3.37.0,<4.0a0|>=3.37.1,<4.0a0|>=3.38.5,<4.0a0|>=3.41.2,<4.0a0|>=3.41.1,<4.0a0|>=3.40.1,<4.0a0|>=3.40.0,<4.0a0|>=3.39.3,<4.0a0|>=3.37.2,<4.0a0']
# defaults/osx-arm64::jsonschema==4.16.0=py310hca03da5_0 -> python[version='>=3.10,<3.11.0a0'] -> sqlite[version='>=3.36.0,<4.0a0|>=3.37.0,<4.0a0|>=3.37.1,<4.0a0|>=3.38.5,<4.0a0|>=3.41.2,<4.0a0|>=3.41.1,<4.0a0|>=3.40.1,<4.0a0|>=3.40.0,<4.0a0|>=3.39.3,<4.0a0|>=3.37.2,<4.0a0']
# defaults/noarch::stack_data==0.2.0=pyhd3eb1b0_0 -> python[version='>=3.5'] -> sqlite[version='3.13.*|3.20.*|>=3.24.0,<4.0a0|>=3.25.1,<4.0a0|>=3.25.2,<4.0a0|>=3.25.3,<4.0a0|>=3.26.0,<4.0a0|>=3.28.0,<4.0a0|>=3.30.1,<4.0a0|>=3.32.3,<4.0a0|>=3.33.0,<4.0a0|>=3.34.0,<4.0a0|>=3.35.5,<4.0a0|>=3.36.0,<4.0a0|>=3.37.0,<4.0a0|>=3.37.1,<4.0a0|>=3.38.5,<4.0a0|3.9.*|>=3.41.2,<4.0a0|>=3.41.1,<4.0a0|>=3.40.1,<4.0a0|>=3.40.0,<4.0a0|>=3.39.3,<4.0a0|>=3.37.2,<4.0a0|>=3.39.2,<4.0a0|>=3.38.3,<4.0a0|>=3.38.2,<4.0a0|>=3.35.4,<4.0a0|>=3.31.1,<4.0a0|>=3.30.0,<4.0a0|>=3.29.0,<4.0a0|>=3.27.2,<4.0a0|>=3.23.1,<4.0a0|>=3.22.0,<4.0a0|>=3.20.1,<4.0a0']
# defaults/osx-arm64::lxml==4.9.1=py310h2fae87d_0 -> python[version='>=3.10,<3.11.0a0'] -> sqlite[version='>=3.36.0,<4.0a0|>=3.37.0,<4.0a0|>=3.37.1,<4.0a0|>=3.38.5,<4.0a0|>=3.41.2,<4.0a0|>=3.41.1,<4.0a0|>=3.40.1,<4.0a0|>=3.40.0,<4.0a0|>=3.39.3,<4.0a0|>=3.37.2,<4.0a0']
# defaults/osx-arm64::qtwebkit==5.212=h0f11f3c_4 -> sqlite[version='>=3.38.5,<4.0a0']
# defaults/osx-arm64::sip==6.6.2=py310hc377ac9_0 -> python[version='>=3.10,<3.11.0a0'] -> sqlite[version='>=3.36.0,<4.0a0|>=3.37.0,<4.0a0|>=3.37.1,<4.0a0|>=3.38.5,<4.0a0|>=3.41.2,<4.0a0|>=3.41.1,<4.0a0|>=3.40.1,<4.0a0|>=3.40.0,<4.0a0|>=3.39.3,<4.0a0|>=3.37.2,<4.0a0']
# defaults/osx-arm64::beautifulsoup4==4.11.1=py310hca03da5_0 -> python[version='>=3.10,<3.11.0a0'] -> sqlite[version='>=3.36.0,<4.0a0|>=3.37.0,<4.0a0|>=3.37.1,<4.0a0|>=3.38.5,<4.0a0|>=3.41.2,<4.0a0|>=3.41.1,<4.0a0|>=3.40.1,<4.0a0|>=3.40.0,<4.0a0|>=3.39.3,<4.0a0|>=3.37.2,<4.0a0']
# defaults/osx-arm64::attrs==22.1.0=py310hca03da5_0 -> python[version='>=3.10,<3.11.0a0'] -> sqlite[version='>=3.36.0,<4.0a0|>=3.37.0,<4.0a0|>=3.37.1,<4.0a0|>=3.38.5,<4.0a0|>=3.41.2,<4.0a0|>=3.41.1,<4.0a0|>=3.40.1,<4.0a0|>=3.40.0,<4.0a0|>=3.39.3,<4.0a0|>=3.37.2,<4.0a0']
# defaults/osx-arm64::ply==3.11=py310hca03da5_0 -> python[version='>=3.10,<3.11.0a0'] -> sqlite[version='>=3.36.0,<4.0a0|>=3.37.0,<4.0a0|>=3.37.1,<4.0a0|>=3.38.5,<4.0a0|>=3.41.2,<4.0a0|>=3.41.1,<4.0a0|>=3.40.1,<4.0a0|>=3.40.0,<4.0a0|>=3.39.3,<4.0a0|>=3.37.2,<4.0a0']
# defaults/noarch::python-dateutil==2.8.2=pyhd3eb1b0_0 -> python -> sqlite[version='3.13.*|3.20.*|>=3.24.0,<4.0a0|>=3.25.1,<4.0a0|>=3.25.2,<4.0a0|>=3.25.3,<4.0a0|>=3.26.0,<4.0a0|>=3.28.0,<4.0a0|>=3.30.1,<4.0a0|>=3.32.3,<4.0a0|>=3.33.0,<4.0a0|>=3.34.0,<4.0a0|>=3.35.5,<4.0a0|>=3.36.0,<4.0a0|>=3.37.0,<4.0a0|>=3.37.1,<4.0a0|>=3.38.5,<4.0a0|3.9.*|>=3.41.2,<4.0a0|>=3.41.1,<4.0a0|>=3.40.1,<4.0a0|>=3.40.0,<4.0a0|>=3.39.3,<4.0a0|>=3.37.2,<4.0a0|>=3.39.2,<4.0a0|>=3.38.3,<4.0a0|>=3.38.2,<4.0a0|>=3.35.4,<4.0a0|>=3.31.1,<4.0a0|>=3.30.0,<4.0a0|>=3.29.0,<4.0a0|>=3.27.2,<4.0a0|>=3.23.1,<4.0a0|>=3.22.0,<4.0a0|>=3.20.1,<4.0a0']
# defaults/noarch::pygments==2.11.2=pyhd3eb1b0_0 -> python[version='>=3.5'] -> sqlite[version='3.13.*|3.20.*|>=3.24.0,<4.0a0|>=3.25.1,<4.0a0|>=3.25.2,<4.0a0|>=3.25.3,<4.0a0|>=3.26.0,<4.0a0|>=3.28.0,<4.0a0|>=3.30.1,<4.0a0|>=3.32.3,<4.0a0|>=3.33.0,<4.0a0|>=3.34.0,<4.0a0|>=3.35.5,<4.0a0|>=3.36.0,<4.0a0|>=3.37.0,<4.0a0|>=3.37.1,<4.0a0|>=3.38.5,<4.0a0|3.9.*|>=3.41.2,<4.0a0|>=3.41.1,<4.0a0|>=3.40.1,<4.0a0|>=3.40.0,<4.0a0|>=3.39.3,<4.0a0|>=3.37.2,<4.0a0|>=3.39.2,<4.0a0|>=3.38.3,<4.0a0|>=3.38.2,<4.0a0|>=3.35.4,<4.0a0|>=3.31.1,<4.0a0|>=3.30.0,<4.0a0|>=3.29.0,<4.0a0|>=3.27.2,<4.0a0|>=3.23.1,<4.0a0|>=3.22.0,<4.0a0|>=3.20.1,<4.0a0']
# defaults/osx-arm64::qt-main==5.15.2=ha2d02b5_7 -> nss[version='>=3.74,<4.0a0'] -> sqlite[version='>=3.37.0,<4.0a0|>=3.37.1,<4.0a0|>=3.38.5,<4.0a0']
# defaults/osx-arm64::typing-extensions==4.4.0=py310hca03da5_0 -> python[version='>=3.10,<3.11.0a0'] -> sqlite[version='>=3.36.0,<4.0a0|>=3.37.0,<4.0a0|>=3.37.1,<4.0a0|>=3.38.5,<4.0a0|>=3.41.2,<4.0a0|>=3.41.1,<4.0a0|>=3.40.1,<4.0a0|>=3.40.0,<4.0a0|>=3.39.3,<4.0a0|>=3.37.2,<4.0a0']
# defaults/osx-arm64::appnope==0.1.2=py310hca03da5_1001 -> python[version='>=3.10,<3.11.0a0'] -> sqlite[version='>=3.36.0,<4.0a0|>=3.37.0,<4.0a0|>=3.37.1,<4.0a0|>=3.38.5,<4.0a0|>=3.41.2,<4.0a0|>=3.41.1,<4.0a0|>=3.40.1,<4.0a0|>=3.40.0,<4.0a0|>=3.39.3,<4.0a0|>=3.37.2,<4.0a0']
# defaults/osx-arm64::babel==2.11.0=py310hca03da5_0 -> python[version='>=3.10,<3.11.0a0'] -> sqlite[version='>=3.36.0,<4.0a0|>=3.37.0,<4.0a0|>=3.37.1,<4.0a0|>=3.38.5,<4.0a0|>=3.41.2,<4.0a0|>=3.41.1,<4.0a0|>=3.40.1,<4.0a0|>=3.40.0,<4.0a0|>=3.39.3,<4.0a0|>=3.37.2,<4.0a0']
# defaults/osx-arm64::nbconvert==6.5.4=py310hca03da5_0 -> python[version='>=3.10,<3.11.0a0'] -> sqlite[version='>=3.36.0,<4.0a0|>=3.37.0,<4.0a0|>=3.37.1,<4.0a0|>=3.38.5,<4.0a0|>=3.41.2,<4.0a0|>=3.41.1,<4.0a0|>=3.40.1,<4.0a0|>=3.40.0,<4.0a0|>=3.39.3,<4.0a0|>=3.37.2,<4.0a0']
# defaults/osx-arm64::typing_extensions==4.4.0=py310hca03da5_0 -> python[version='>=3.10,<3.11.0a0'] -> sqlite[version='>=3.36.0,<4.0a0|>=3.37.0,<4.0a0|>=3.37.1,<4.0a0|>=3.38.5,<4.0a0|>=3.41.2,<4.0a0|>=3.41.1,<4.0a0|>=3.40.1,<4.0a0|>=3.40.0,<4.0a0|>=3.39.3,<4.0a0|>=3.37.2,<4.0a0']
# defaults/noarch::toml==0.10.2=pyhd3eb1b0_0 -> python[version='>=2.7'] -> sqlite[version='3.13.*|3.20.*|>=3.24.0,<4.0a0|>=3.25.1,<4.0a0|>=3.25.2,<4.0a0|>=3.25.3,<4.0a0|>=3.26.0,<4.0a0|>=3.28.0,<4.0a0|>=3.30.1,<4.0a0|>=3.32.3,<4.0a0|>=3.33.0,<4.0a0|>=3.34.0,<4.0a0|>=3.35.5,<4.0a0|>=3.36.0,<4.0a0|>=3.37.0,<4.0a0|>=3.37.1,<4.0a0|>=3.38.5,<4.0a0|3.9.*|>=3.41.2,<4.0a0|>=3.41.1,<4.0a0|>=3.40.1,<4.0a0|>=3.40.0,<4.0a0|>=3.39.3,<4.0a0|>=3.37.2,<4.0a0|>=3.39.2,<4.0a0|>=3.38.3,<4.0a0|>=3.38.2,<4.0a0|>=3.35.4,<4.0a0|>=3.31.1,<4.0a0|>=3.30.0,<4.0a0|>=3.29.0,<4.0a0|>=3.27.2,<4.0a0|>=3.23.1,<4.0a0|>=3.22.0,<4.0a0|>=3.20.1,<4.0a0']
# defaults/noarch::backcall==0.2.0=pyhd3eb1b0_0 -> python -> sqlite[version='3.13.*|3.20.*|>=3.24.0,<4.0a0|>=3.25.1,<4.0a0|>=3.25.2,<4.0a0|>=3.25.3,<4.0a0|>=3.26.0,<4.0a0|>=3.28.0,<4.0a0|>=3.30.1,<4.0a0|>=3.32.3,<4.0a0|>=3.33.0,<4.0a0|>=3.34.0,<4.0a0|>=3.35.5,<4.0a0|>=3.36.0,<4.0a0|>=3.37.0,<4.0a0|>=3.37.1,<4.0a0|>=3.38.5,<4.0a0|3.9.*|>=3.41.2,<4.0a0|>=3.41.1,<4.0a0|>=3.40.1,<4.0a0|>=3.40.0,<4.0a0|>=3.39.3,<4.0a0|>=3.37.2,<4.0a0|>=3.39.2,<4.0a0|>=3.38.3,<4.0a0|>=3.38.2,<4.0a0|>=3.35.4,<4.0a0|>=3.31.1,<4.0a0|>=3.30.0,<4.0a0|>=3.29.0,<4.0a0|>=3.27.2,<4.0a0|>=3.23.1,<4.0a0|>=3.22.0,<4.0a0|>=3.20.1,<4.0a0']
# defaults/osx-arm64::ipython==8.8.0=py310hca03da5_0 -> python[version='>=3.10,<3.11.0a0'] -> sqlite[version='>=3.36.0,<4.0a0|>=3.37.0,<4.0a0|>=3.37.1,<4.0a0|>=3.38.5,<4.0a0|>=3.41.2,<4.0a0|>=3.41.1,<4.0a0|>=3.40.1,<4.0a0|>=3.40.0,<4.0a0|>=3.39.3,<4.0a0|>=3.37.2,<4.0a0']
# defaults/osx-arm64::prometheus_client==0.14.1=py310hca03da5_0 -> python[version='>=3.10,<3.11.0a0'] -> sqlite[version='>=3.36.0,<4.0a0|>=3.37.0,<4.0a0|>=3.37.1,<4.0a0|>=3.38.5,<4.0a0|>=3.41.2,<4.0a0|>=3.41.1,<4.0a0|>=3.40.1,<4.0a0|>=3.40.0,<4.0a0|>=3.39.3,<4.0a0|>=3.37.2,<4.0a0']
# defaults/osx-arm64::widgetsnbextension==3.5.2=py310hca03da5_0 -> python[version='>=3.10,<3.11.0a0'] -> sqlite[version='>=3.36.0,<4.0a0|>=3.37.0,<4.0a0|>=3.37.1,<4.0a0|>=3.38.5,<4.0a0|>=3.41.2,<4.0a0|>=3.41.1,<4.0a0|>=3.40.1,<4.0a0|>=3.40.0,<4.0a0|>=3.39.3,<4.0a0|>=3.37.2,<4.0a0']
# defaults/osx-arm64::brotlipy==0.7.0=py310h1a28f6b_1002 -> python[version='>=3.10,<3.11.0a0'] -> sqlite[version='>=3.36.0,<4.0a0|>=3.37.0,<4.0a0|>=3.37.1,<4.0a0|>=3.38.5,<4.0a0|>=3.41.2,<4.0a0|>=3.41.1,<4.0a0|>=3.40.1,<4.0a0|>=3.40.0,<4.0a0|>=3.39.3,<4.0a0|>=3.37.2,<4.0a0']
# defaults/noarch::ipython_genutils==0.2.0=pyhd3eb1b0_1 -> python -> sqlite[version='3.13.*|3.20.*|>=3.24.0,<4.0a0|>=3.25.1,<4.0a0|>=3.25.2,<4.0a0|>=3.25.3,<4.0a0|>=3.26.0,<4.0a0|>=3.28.0,<4.0a0|>=3.30.1,<4.0a0|>=3.32.3,<4.0a0|>=3.33.0,<4.0a0|>=3.34.0,<4.0a0|>=3.35.5,<4.0a0|>=3.36.0,<4.0a0|>=3.37.0,<4.0a0|>=3.37.1,<4.0a0|>=3.38.5,<4.0a0|3.9.*|>=3.41.2,<4.0a0|>=3.41.1,<4.0a0|>=3.40.1,<4.0a0|>=3.40.0,<4.0a0|>=3.39.3,<4.0a0|>=3.37.2,<4.0a0|>=3.39.2,<4.0a0|>=3.38.3,<4.0a0|>=3.38.2,<4.0a0|>=3.35.4,<4.0a0|>=3.31.1,<4.0a0|>=3.30.0,<4.0a0|>=3.29.0,<4.0a0|>=3.27.2,<4.0a0|>=3.23.1,<4.0a0|>=3.22.0,<4.0a0|>=3.20.1,<4.0a0']
# defaults/osx-arm64::markupsafe==2.1.1=py310h1a28f6b_0 -> python[version='>=3.10,<3.11.0a0'] -> sqlite[version='>=3.36.0,<4.0a0|>=3.37.0,<4.0a0|>=3.37.1,<4.0a0|>=3.38.5,<4.0a0|>=3.41.2,<4.0a0|>=3.41.1,<4.0a0|>=3.40.1,<4.0a0|>=3.40.0,<4.0a0|>=3.39.3,<4.0a0|>=3.37.2,<4.0a0']
# defaults/noarch::parso==0.8.3=pyhd3eb1b0_0 -> python[version='>=3.6'] -> sqlite[version='3.13.*|3.20.*|>=3.24.0,<4.0a0|>=3.25.1,<4.0a0|>=3.25.2,<4.0a0|>=3.25.3,<4.0a0|>=3.26.0,<4.0a0|>=3.28.0,<4.0a0|>=3.30.1,<4.0a0|>=3.32.3,<4.0a0|>=3.33.0,<4.0a0|>=3.34.0,<4.0a0|>=3.35.5,<4.0a0|>=3.36.0,<4.0a0|>=3.37.0,<4.0a0|>=3.37.1,<4.0a0|>=3.38.5,<4.0a0|>=3.41.2,<4.0a0|>=3.41.1,<4.0a0|>=3.40.1,<4.0a0|>=3.40.0,<4.0a0|>=3.39.3,<4.0a0|>=3.37.2,<4.0a0|>=3.39.2,<4.0a0|>=3.38.3,<4.0a0|>=3.38.2,<4.0a0|>=3.35.4,<4.0a0|>=3.31.1,<4.0a0|>=3.30.0,<4.0a0|>=3.29.0,<4.0a0|>=3.27.2,<4.0a0|>=3.23.1,<4.0a0|>=3.22.0,<4.0a0|>=3.20.1,<4.0a0']
# defaults/osx-arm64::biopython==1.78=py310h1a28f6b_0 -> python[version='>=3.10,<3.11.0a0'] -> sqlite[version='>=3.36.0,<4.0a0|>=3.37.0,<4.0a0|>=3.37.1,<4.0a0|>=3.38.5,<4.0a0|>=3.41.2,<4.0a0|>=3.41.1,<4.0a0|>=3.40.1,<4.0a0|>=3.40.0,<4.0a0|>=3.39.3,<4.0a0|>=3.37.2,<4.0a0']
# defaults/osx-arm64::jupyter_client==7.4.8=py310hca03da5_0 -> python[version='>=3.10,<3.11.0a0'] -> sqlite[version='>=3.36.0,<4.0a0|>=3.37.0,<4.0a0|>=3.37.1,<4.0a0|>=3.38.5,<4.0a0|>=3.41.2,<4.0a0|>=3.41.1,<4.0a0|>=3.40.1,<4.0a0|>=3.40.0,<4.0a0|>=3.39.3,<4.0a0|>=3.37.2,<4.0a0']
# defaults/osx-arm64::qtwebkit==5.212=h0f11f3c_4 -> qt-main[version='>=5.15.2,<5.16.0a0'] -> sqlite[version='>=3.37.0,<4.0a0|>=3.38.2,<4.0a0|>=3.41.1,<4.0a0|>=3.39.2,<4.0a0']
# defaults/osx-arm64::packaging==22.0=py310hca03da5_0 -> python[version='>=3.10,<3.11.0a0'] -> sqlite[version='>=3.36.0,<4.0a0|>=3.37.0,<4.0a0|>=3.37.1,<4.0a0|>=3.38.5,<4.0a0|>=3.41.2,<4.0a0|>=3.41.1,<4.0a0|>=3.40.1,<4.0a0|>=3.40.0,<4.0a0|>=3.39.3,<4.0a0|>=3.37.2,<4.0a0']
# defaults/noarch::argon2-cffi==21.3.0=pyhd3eb1b0_0 -> python[version='>=3.6'] -> sqlite[version='3.13.*|3.20.*|>=3.24.0,<4.0a0|>=3.25.1,<4.0a0|>=3.25.2,<4.0a0|>=3.25.3,<4.0a0|>=3.26.0,<4.0a0|>=3.28.0,<4.0a0|>=3.30.1,<4.0a0|>=3.32.3,<4.0a0|>=3.33.0,<4.0a0|>=3.34.0,<4.0a0|>=3.35.5,<4.0a0|>=3.36.0,<4.0a0|>=3.37.0,<4.0a0|>=3.37.1,<4.0a0|>=3.38.5,<4.0a0|>=3.41.2,<4.0a0|>=3.41.1,<4.0a0|>=3.40.1,<4.0a0|>=3.40.0,<4.0a0|>=3.39.3,<4.0a0|>=3.37.2,<4.0a0|>=3.39.2,<4.0a0|>=3.38.3,<4.0a0|>=3.38.2,<4.0a0|>=3.35.4,<4.0a0|>=3.31.1,<4.0a0|>=3.30.0,<4.0a0|>=3.29.0,<4.0a0|>=3.27.2,<4.0a0|>=3.23.1,<4.0a0|>=3.22.0,<4.0a0|>=3.20.1,<4.0a0']
# defaults/osx-arm64::cffi==1.15.1=py310h80987f9_3 -> python[version='>=3.10,<3.11.0a0'] -> sqlite[version='>=3.36.0,<4.0a0|>=3.37.0,<4.0a0|>=3.37.1,<4.0a0|>=3.38.5,<4.0a0|>=3.41.2,<4.0a0|>=3.41.1,<4.0a0|>=3.40.1,<4.0a0|>=3.40.0,<4.0a0|>=3.39.3,<4.0a0|>=3.37.2,<4.0a0']
# defaults/osx-arm64::matplotlib-inline==0.1.6=py310hca03da5_0 -> python[version='>=3.10,<3.11.0a0'] -> sqlite[version='>=3.36.0,<4.0a0|>=3.37.0,<4.0a0|>=3.37.1,<4.0a0|>=3.38.5,<4.0a0|>=3.41.2,<4.0a0|>=3.41.1,<4.0a0|>=3.40.1,<4.0a0|>=3.40.0,<4.0a0|>=3.39.3,<4.0a0|>=3.37.2,<4.0a0']
# defaults/noarch::ipywidgets==7.6.5=pyhd3eb1b0_1 -> python -> sqlite[version='3.13.*|3.20.*|>=3.24.0,<4.0a0|>=3.25.1,<4.0a0|>=3.25.2,<4.0a0|>=3.25.3,<4.0a0|>=3.26.0,<4.0a0|>=3.28.0,<4.0a0|>=3.30.1,<4.0a0|>=3.32.3,<4.0a0|>=3.33.0,<4.0a0|>=3.34.0,<4.0a0|>=3.35.5,<4.0a0|>=3.36.0,<4.0a0|>=3.37.0,<4.0a0|>=3.37.1,<4.0a0|>=3.38.5,<4.0a0|3.9.*|>=3.41.2,<4.0a0|>=3.41.1,<4.0a0|>=3.40.1,<4.0a0|>=3.40.0,<4.0a0|>=3.39.3,<4.0a0|>=3.37.2,<4.0a0|>=3.39.2,<4.0a0|>=3.38.3,<4.0a0|>=3.38.2,<4.0a0|>=3.35.4,<4.0a0|>=3.31.1,<4.0a0|>=3.30.0,<4.0a0|>=3.29.0,<4.0a0|>=3.27.2,<4.0a0|>=3.23.1,<4.0a0|>=3.22.0,<4.0a0|>=3.20.1,<4.0a0']
# defaults/osx-arm64::mistune==0.8.4=py310h1a28f6b_1000 -> python[version='>=3.10,<3.11.0a0'] -> sqlite[version='>=3.36.0,<4.0a0|>=3.37.0,<4.0a0|>=3.37.1,<4.0a0|>=3.38.5,<4.0a0|>=3.41.2,<4.0a0|>=3.41.1,<4.0a0|>=3.40.1,<4.0a0|>=3.40.0,<4.0a0|>=3.39.3,<4.0a0|>=3.37.2,<4.0a0']
# defaults/osx-arm64::pyqt5-sip==12.11.0=py310hc377ac9_0 -> python[version='>=3.10,<3.11.0a0'] -> sqlite[version='>=3.36.0,<4.0a0|>=3.37.0,<4.0a0|>=3.37.1,<4.0a0|>=3.38.5,<4.0a0|>=3.41.2,<4.0a0|>=3.41.1,<4.0a0|>=3.40.1,<4.0a0|>=3.40.0,<4.0a0|>=3.39.3,<4.0a0|>=3.37.2,<4.0a0']
# defaults/osx-arm64::python.app==3=py310h1a28f6b_0 -> python[version='>=3.10,<3.11.0a0'] -> sqlite[version='>=3.36.0,<4.0a0|>=3.37.0,<4.0a0|>=3.37.1,<4.0a0|>=3.38.5,<4.0a0|>=3.41.2,<4.0a0|>=3.41.1,<4.0a0|>=3.40.1,<4.0a0|>=3.40.0,<4.0a0|>=3.39.3,<4.0a0|>=3.37.2,<4.0a0']
# defaults/noarch::wheel==0.37.1=pyhd3eb1b0_0 -> python -> sqlite[version='3.13.*|3.20.*|>=3.24.0,<4.0a0|>=3.25.1,<4.0a0|>=3.25.2,<4.0a0|>=3.25.3,<4.0a0|>=3.26.0,<4.0a0|>=3.28.0,<4.0a0|>=3.30.1,<4.0a0|>=3.32.3,<4.0a0|>=3.33.0,<4.0a0|>=3.34.0,<4.0a0|>=3.35.5,<4.0a0|>=3.36.0,<4.0a0|>=3.37.0,<4.0a0|>=3.37.1,<4.0a0|>=3.38.5,<4.0a0|3.9.*|>=3.41.2,<4.0a0|>=3.41.1,<4.0a0|>=3.40.1,<4.0a0|>=3.40.0,<4.0a0|>=3.39.3,<4.0a0|>=3.37.2,<4.0a0|>=3.39.2,<4.0a0|>=3.38.3,<4.0a0|>=3.38.2,<4.0a0|>=3.35.4,<4.0a0|>=3.31.1,<4.0a0|>=3.30.0,<4.0a0|>=3.29.0,<4.0a0|>=3.27.2,<4.0a0|>=3.23.1,<4.0a0|>=3.22.0,<4.0a0|>=3.20.1,<4.0a0']
# defaults/osx-arm64::jupyter_core==5.1.1=py310hca03da5_0 -> python[version='>=3.10,<3.11.0a0'] -> sqlite[version='>=3.36.0,<4.0a0|>=3.37.0,<4.0a0|>=3.37.1,<4.0a0|>=3.38.5,<4.0a0|>=3.41.2,<4.0a0|>=3.41.1,<4.0a0|>=3.40.1,<4.0a0|>=3.40.0,<4.0a0|>=3.39.3,<4.0a0|>=3.37.2,<4.0a0']
# defaults/noarch::flit-core==3.6.0=pyhd3eb1b0_0 -> python[version='>=3.6'] -> sqlite[version='3.13.*|3.20.*|>=3.24.0,<4.0a0|>=3.25.1,<4.0a0|>=3.25.2,<4.0a0|>=3.25.3,<4.0a0|>=3.26.0,<4.0a0|>=3.28.0,<4.0a0|>=3.30.1,<4.0a0|>=3.32.3,<4.0a0|>=3.33.0,<4.0a0|>=3.34.0,<4.0a0|>=3.35.5,<4.0a0|>=3.36.0,<4.0a0|>=3.37.0,<4.0a0|>=3.37.1,<4.0a0|>=3.38.5,<4.0a0|>=3.41.2,<4.0a0|>=3.41.1,<4.0a0|>=3.40.1,<4.0a0|>=3.40.0,<4.0a0|>=3.39.3,<4.0a0|>=3.37.2,<4.0a0|>=3.39.2,<4.0a0|>=3.38.3,<4.0a0|>=3.38.2,<4.0a0|>=3.35.4,<4.0a0|>=3.31.1,<4.0a0|>=3.30.0,<4.0a0|>=3.29.0,<4.0a0|>=3.27.2,<4.0a0|>=3.23.1,<4.0a0|>=3.22.0,<4.0a0|>=3.20.1,<4.0a0']
# defaults/osx-arm64::entrypoints==0.4=py310hca03da5_0 -> python[version='>=3.10,<3.11.0a0'] -> sqlite[version='>=3.36.0,<4.0a0|>=3.37.0,<4.0a0|>=3.37.1,<4.0a0|>=3.38.5,<4.0a0|>=3.41.2,<4.0a0|>=3.41.1,<4.0a0|>=3.40.1,<4.0a0|>=3.40.0,<4.0a0|>=3.39.3,<4.0a0|>=3.37.2,<4.0a0']
# defaults/osx-arm64::anyio==3.5.0=py310hca03da5_0 -> python[version='>=3.10,<3.11.0a0'] -> sqlite[version='>=3.36.0,<4.0a0|>=3.37.0,<4.0a0|>=3.37.1,<4.0a0|>=3.38.5,<4.0a0|>=3.41.2,<4.0a0|>=3.41.1,<4.0a0|>=3.40.1,<4.0a0|>=3.40.0,<4.0a0|>=3.39.3,<4.0a0|>=3.37.2,<4.0a0']
# defaults/osx-arm64::idna==3.4=py310hca03da5_0 -> python[version='>=3.10,<3.11.0a0'] -> sqlite[version='>=3.36.0,<4.0a0|>=3.37.0,<4.0a0|>=3.37.1,<4.0a0|>=3.38.5,<4.0a0|>=3.41.2,<4.0a0|>=3.41.1,<4.0a0|>=3.40.1,<4.0a0|>=3.40.0,<4.0a0|>=3.39.3,<4.0a0|>=3.37.2,<4.0a0']
# defaults/osx-arm64::jinja2==3.1.2=py310hca03da5_0 -> python[version='>=3.10,<3.11.0a0'] -> sqlite[version='>=3.36.0,<4.0a0|>=3.37.0,<4.0a0|>=3.37.1,<4.0a0|>=3.38.5,<4.0a0|>=3.41.2,<4.0a0|>=3.41.1,<4.0a0|>=3.40.1,<4.0a0|>=3.40.0,<4.0a0|>=3.39.3,<4.0a0|>=3.37.2,<4.0a0']
# defaults/noarch::ptyprocess==0.7.0=pyhd3eb1b0_2 -> python -> sqlite[version='3.13.*|3.20.*|>=3.24.0,<4.0a0|>=3.25.1,<4.0a0|>=3.25.2,<4.0a0|>=3.25.3,<4.0a0|>=3.26.0,<4.0a0|>=3.28.0,<4.0a0|>=3.30.1,<4.0a0|>=3.32.3,<4.0a0|>=3.33.0,<4.0a0|>=3.34.0,<4.0a0|>=3.35.5,<4.0a0|>=3.36.0,<4.0a0|>=3.37.0,<4.0a0|>=3.37.1,<4.0a0|>=3.38.5,<4.0a0|3.9.*|>=3.41.2,<4.0a0|>=3.41.1,<4.0a0|>=3.40.1,<4.0a0|>=3.40.0,<4.0a0|>=3.39.3,<4.0a0|>=3.37.2,<4.0a0|>=3.39.2,<4.0a0|>=3.38.3,<4.0a0|>=3.38.2,<4.0a0|>=3.35.4,<4.0a0|>=3.31.1,<4.0a0|>=3.30.0,<4.0a0|>=3.29.0,<4.0a0|>=3.27.2,<4.0a0|>=3.23.1,<4.0a0|>=3.22.0,<4.0a0|>=3.20.1,<4.0a0']
# defaults/osx-arm64::webencodings==0.5.1=py310hca03da5_1 -> python[version='>=3.10,<3.11.0a0'] -> sqlite[version='>=3.36.0,<4.0a0|>=3.37.0,<4.0a0|>=3.37.1,<4.0a0|>=3.38.5,<4.0a0|>=3.41.2,<4.0a0|>=3.41.1,<4.0a0|>=3.40.1,<4.0a0|>=3.40.0,<4.0a0|>=3.39.3,<4.0a0|>=3.37.2,<4.0a0']
# ...
#
# Package libcblas conflicts for:
# defaults/osx-arm64::numpy==1.23.5=py310hb93e574_0 -> blas=[build=openblas] -> libcblas[version='3.8.0|3.8.0|3.8.0|3.8.0|3.8.0|3.8.0|3.8.0|3.8.0|3.8.0|3.8.0|3.8.0|3.8.0|3.8.0|3.8.0|3.9.0|3.9.0|3.9.0',build='3_openblas|4_openblas|5_openblas|6_openblas|7_openblas|9_openblas|13_openblas|15_openblas|5_openblas|12_osx64_openblas|15_osx64_openblas|16_osx64_openblas|16_osxarm64_openblas|14_osx64_openblas|13_osx64_openblas|11_osx64_openblas|10_openblas|9_openblas|8_openblas|7_openblas|6_openblas|17_openblas|16_openblas|14_openblas|12_openblas|11_openblas|10_openblas|8_openblas|2_openblas']
# defaults/osx-arm64::numpy-base==1.23.5=py310haf87e8b_0 -> blas=[build=openblas] -> libcblas[version='3.8.0|3.8.0|3.8.0|3.8.0|3.8.0|3.8.0|3.8.0|3.8.0|3.8.0|3.8.0|3.8.0|3.8.0|3.8.0|3.8.0|3.9.0|3.9.0|3.9.0',build='3_openblas|4_openblas|5_openblas|6_openblas|7_openblas|9_openblas|13_openblas|15_openblas|5_openblas|12_osx64_openblas|15_osx64_openblas|16_osx64_openblas|16_osxarm64_openblas|14_osx64_openblas|13_osx64_openblas|11_osx64_openblas|10_openblas|9_openblas|8_openblas|7_openblas|6_openblas|17_openblas|16_openblas|14_openblas|12_openblas|11_openblas|10_openblas|8_openblas|2_openblas']
# conda-forge/osx-arm64::blas-devel==3.9.0=16_osxarm64_openblas -> libcblas==3.9.0=16_osxarm64_openblas
# defaults/osx-arm64::biopython==1.78=py310h1a28f6b_0 -> numpy -> libcblas[version='>=3.8.0,<4.0a0|>=3.9.0,<4.0a0']
# conda-forge/osx-arm64::blas==2.116=openblas -> libcblas==3.9.0=16_osxarm64_openblas
# conda-forge/osx-arm64::liblapacke==3.9.0=16_osxarm64_openblas -> libcblas==3.9.0=16_osxarm64_openblas
#
# Package jupyter_events conflicts for:
# defaults/osx-arm64::nbclassic==0.4.8=py310hca03da5_0 -> jupyter_server[version='>=1.17.0'] -> jupyter_events[version='>=0.4.0']
# defaults/osx-arm64::notebook-shim==0.2.2=py310hca03da5_0 -> jupyter_server[version='>=1.8,<3'] -> jupyter_events[version='>=0.4.0']
# defaults/osx-arm64::jupyterlab_server==2.16.5=py310hca03da5_0 -> jupyter_server[version='>=1.21,<3'] -> jupyter_events[version='>=0.4.0']
# defaults/osx-arm64::jupyterlab==3.5.3=py310hca03da5_0 -> jupyter_server[version='>=1.16,<3'] -> jupyter_events[version='>=0.4.0']
#
# Package pyrsistent conflicts for:
# defaults/osx-arm64::nbformat==5.7.0=py310hca03da5_0 -> jsonschema[version='>=2.6'] -> pyrsistent[version='!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0|>=0.14.0|>=0.14.0,!=0.17.0,!=0.17.1,!=0.17.2']
# defaults/osx-arm64::jsonschema==4.16.0=py310hca03da5_0 -> pyrsistent[version='!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0']
# defaults/osx-arm64::jupyterlab_server==2.16.5=py310hca03da5_0 -> jsonschema[version='>=3.0.1'] -> pyrsistent[version='!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0|>=0.14.0|>=0.14.0,!=0.17.0,!=0.17.1,!=0.17.2']
#
# Package sniffio conflicts for:
# defaults/osx-arm64::jupyter_server==1.23.4=py310hca03da5_0 -> anyio[version='>=3.1.0,<4'] -> sniffio[version='>=1.1']
# defaults/osx-arm64::anyio==3.5.0=py310hca03da5_0 -> sniffio[version='>=1.1']
#
# Package flit-core conflicts for:
# defaults/osx-arm64::typing-extensions==4.4.0=py310hca03da5_0 -> typing_extensions==4.4.0=py310hca03da5_0 -> flit-core[version='>=3.6,<4']
# defaults/osx-arm64::typing_extensions==4.4.0=py310hca03da5_0 -> flit-core[version='>=3.6,<4']
# defaults/osx-arm64::nbclassic==0.4.8=py310hca03da5_0 -> argon2-cffi -> flit-core[version='>=3.4,<4']
# defaults/osx-arm64::jupyter_server==1.23.4=py310hca03da5_0 -> argon2-cffi -> flit-core[version='>=3.4,<4']
# defaults/osx-arm64::notebook==6.5.2=py310hca03da5_0 -> argon2-cffi -> flit-core[version='>=3.4,<4']
#
# Package libxslt conflicts for:
# defaults/osx-arm64::pyqt==5.15.7=py310hc377ac9_0 -> qtwebkit=5 -> libxslt[version='>=1.1.33,<2.0a0|>=1.1.37,<2.0a0|>=1.1.35,<2.0a0']
# defaults/osx-arm64::lxml==4.9.1=py310h2fae87d_0 -> libxslt[version='>=1.1.28|>=1.1.35,<2.0a0']
# defaults/osx-arm64::nbconvert==6.5.4=py310hca03da5_0 -> lxml -> libxslt[version='>=1.1.28|>=1.1.28,<2.0.0a0|>=1.1.32,<2.0a0|>=1.1.33,<2.0a0|>=1.1.35,<2.0a0|>=1.1.37,<2.0a0|>=1.1.34,<2.0a0']
# defaults/osx-arm64::qtwebkit==5.212=h0f11f3c_4 -> libxslt[version='>=1.1.35,<2.0a0']
#
# Package qt-webengine conflicts for:
# defaults/osx-arm64::pyqt==5.15.7=py310hc377ac9_0 -> qt-webengine[version='5.15.*|>=5.15.9,<5.16.0a0']
# defaults/osx-arm64::qtwebkit==5.212=h0f11f3c_4 -> qt-webengine[version='>=5.15.9,<5.16.0a0']
# defaults/osx-arm64::qtconsole==5.4.0=py310hca03da5_0 -> pyqt -> qt-webengine[version='5.15.*|>=5.15.9,<5.16.0a0']
#
# Package tomli conflicts for:
# defaults/osx-arm64::jupyterlab==3.5.3=py310hca03da5_0 -> tomli
# defaults/osx-arm64::jupyter==1.0.0=py310hca03da5_8 -> jupyterlab -> tomli
# defaults/osx-arm64::pyqt5-sip==12.11.0=py310hc377ac9_0 -> sip -> tomli
#
# Package nbclient conflicts for:
# defaults/osx-arm64::nbclassic==0.4.8=py310hca03da5_0 -> nbconvert[version='>=5'] -> nbclient[version='>=0.5.0|>=0.5.0,<0.6.0']
# defaults/osx-arm64::jupyter_server==1.23.4=py310hca03da5_0 -> nbconvert[version='>=6.4.4'] -> nbclient[version='>=0.5.0|>=0.5.0,<0.6.0']
# defaults/osx-arm64::jupyter==1.0.0=py310hca03da5_8 -> nbconvert -> nbclient[version='>=0.5.0|>=0.5.0,<0.6.0']
# defaults/osx-arm64::nbconvert==6.5.4=py310hca03da5_0 -> nbclient[version='>=0.5.0']
# defaults/osx-arm64::notebook==6.5.2=py310hca03da5_0 -> nbconvert[version='>=5'] -> nbclient[version='>=0.5.0|>=0.5.0,<0.6.0']
#
# Package libgfortran4 conflicts for:
# defaults/osx-arm64::numpy==1.23.5=py310hb93e574_0 -> blas=[build=openblas] -> libgfortran4[version='>=7.5.0']
# defaults/osx-arm64::numpy-base==1.23.5=py310haf87e8b_0 -> blas=[build=openblas] -> libgfortran4[version='>=7.5.0']
#
# Package cryptography-vectors conflicts for:
# defaults/osx-arm64::conda-content-trust==0.1.3=py310hca03da5_0 -> cryptography -> cryptography-vectors[version='2.3.*|2.3.1.*']
# defaults/osx-arm64::urllib3==1.26.13=py310hca03da5_0 -> cryptography[version='>=1.3.4'] -> cryptography-vectors[version='2.3.*|2.3.1.*']
#
# Package jupyterlab_server conflicts for:
# defaults/osx-arm64::jupyter==1.0.0=py310hca03da5_8 -> jupyterlab -> jupyterlab_server[version='>=0.2.0,<0.3.0|>=1.0.0,<2.0.0|>=1.1.0,<2.0.0|>=2,<3|>=2.10,<3|>=2.19,<3|>=2.3,<3|>=2.0.0,<3.0.0|>=1.1.5,<2.0.0']
# defaults/osx-arm64::jupyterlab==3.5.3=py310hca03da5_0 -> jupyterlab_server[version='>=2.10,<3']
#
# Package mysql-libs conflicts for:
# defaults/osx-arm64::qt-webengine==5.15.9=h2903aaf_4 -> qt-main[version='>=5.15,<6.0a0'] -> mysql-libs[version='>=8.0.27,<8.1.0a0|>=8.0.28,<8.1.0a0|>=8.0.29,<8.1.0a0|>=8.0.30,<8.1.0a0|>=8.0.31,<8.1.0a0|>=8.0.32,<8.1.0a0']
# defaults/osx-arm64::pyqt==5.15.7=py310hc377ac9_0 -> qt-main=5.15 -> mysql-libs[version='>=8.0.27,<8.1.0a0|>=8.0.28,<8.1.0a0|>=8.0.29,<8.1.0a0|>=8.0.30,<8.1.0a0|>=8.0.31,<8.1.0a0|>=8.0.32,<8.1.0a0']
# defaults/osx-arm64::qtwebkit==5.212=h0f11f3c_4 -> qt-main[version='>=5.15.2,<5.16.0a0'] -> mysql-libs[version='>=8.0.27,<8.1.0a0|>=8.0.28,<8.1.0a0|>=8.0.29,<8.1.0a0|>=8.0.30,<8.1.0a0|>=8.0.31,<8.1.0a0|>=8.0.32,<8.1.0a0']
#
# Package psutil conflicts for:
# defaults/osx-arm64::notebook==6.5.2=py310hca03da5_0 -> ipykernel -> psutil
# defaults/osx-arm64::jupyter_console==6.4.4=py310hca03da5_0 -> ipykernel -> psutil
# defaults/osx-arm64::qtconsole==5.4.0=py310hca03da5_0 -> ipykernel[version='>=4.1'] -> psutil
# defaults/osx-arm64::jupyter==1.0.0=py310hca03da5_8 -> ipykernel -> psutil
# defaults/noarch::ipywidgets==7.6.5=pyhd3eb1b0_1 -> ipykernel[version='>=4.5.1'] -> psutil
# defaults/osx-arm64::ipykernel==6.19.2=py310h33ce5c2_0 -> psutil
# defaults/osx-arm64::nbclassic==0.4.8=py310hca03da5_0 -> ipykernel -> psutil
#
# Package py conflicts for:
# defaults/osx-arm64::notebook==6.5.2=py310hca03da5_0 -> pyzmq[version='>=17'] -> py
# defaults/osx-arm64::qtconsole==5.4.0=py310hca03da5_0 -> pyzmq[version='>=17.1'] -> py
# defaults/osx-arm64::jupyter_client==7.4.8=py310hca03da5_0 -> pyzmq[version='>=23.0'] -> py
# defaults/osx-arm64::ipykernel==6.19.2=py310h33ce5c2_0 -> pyzmq[version='>=17'] -> py
# defaults/osx-arm64::jupyter_server==1.23.4=py310hca03da5_0 -> pyzmq[version='>=17'] -> py
# defaults/osx-arm64::nbclassic==0.4.8=py310hca03da5_0 -> pyzmq[version='>=17'] -> py
#
# Package blas-devel conflicts for:
# conda-forge/osx-arm64::blas==2.116=openblas -> blas-devel==3.9.0=16_osxarm64_openblas
# defaults/osx-arm64::numpy==1.23.5=py310hb93e574_0 -> blas=[build=openblas] -> blas-devel==3.9.0[build='12_osx64_openblas|15_osx64_openblas|16_osx64_openblas|16_osxarm64_openblas|14_osx64_openblas|13_osx64_openblas|11_osx64_openblas|10_openblas|9_openblas|8_openblas|7_openblas']
# defaults/osx-arm64::numpy-base==1.23.5=py310haf87e8b_0 -> blas=[build=openblas] -> blas-devel==3.9.0[build='12_osx64_openblas|15_osx64_openblas|16_osx64_openblas|16_osxarm64_openblas|14_osx64_openblas|13_osx64_openblas|11_osx64_openblas|10_openblas|9_openblas|8_openblas|7_openblas']
#
# Package asttokens conflicts for:
# defaults/osx-arm64::ipython==8.8.0=py310hca03da5_0 -> stack_data -> asttokens
# defaults/noarch::stack_data==0.2.0=pyhd3eb1b0_0 -> asttokens
#
# Package blas conflicts for:
# defaults/osx-arm64::biopython==1.78=py310h1a28f6b_0 -> numpy -> blas[version='*|*|1.0|1.1|1.0',build='openblas|mkl|openblas|openblas|mkl']
# defaults/osx-arm64::numpy-base==1.23.5=py310haf87e8b_0 -> blas=[build=openblas]
# defaults/osx-arm64::numpy==1.23.5=py310hb93e574_0 -> blas=[build=openblas]
# conda-forge/osx-arm64::blas-devel==3.9.0=16_osxarm64_openblas -> openblas=0.3.21 -> blas==1.0=openblas
#
# Package python-simplegeneric conflicts for:
# defaults/osx-arm64::jupyter_console==6.4.4=py310hca03da5_0 -> ipython -> python-simplegeneric[version='>0.8']
# defaults/osx-arm64::jupyterlab==3.5.3=py310hca03da5_0 -> ipython -> python-simplegeneric[version='>0.8']
# defaults/noarch::ipywidgets==7.6.5=pyhd3eb1b0_1 -> ipython[version='>=4.0.0'] -> python-simplegeneric[version='>0.8']
#
# Package backports.functools_lru_cache conflicts for:
# defaults/osx-arm64::beautifulsoup4==4.11.1=py310hca03da5_0 -> soupsieve[version='>=1.2'] -> backports.functools_lru_cache
# defaults/osx-arm64::prompt-toolkit==3.0.36=py310hca03da5_0 -> wcwidth -> backports.functools_lru_cache
#
# Package pure_eval conflicts for:
# defaults/noarch::stack_data==0.2.0=pyhd3eb1b0_0 -> pure_eval
# defaults/osx-arm64::ipython==8.8.0=py310hca03da5_0 -> stack_data -> pure_eval
#
# Package jupyterlab_widgets conflicts for:
# defaults/osx-arm64::jupyter==1.0.0=py310hca03da5_8 -> ipywidgets -> jupyterlab_widgets[version='>=1.0.0|>=1.0.0,<2.0.0|>=1.0.0,<3|>=3.0.0,<4.0.0|>=3.0.4,<4.0.0|>=3.0.7,<4.1.dev0']
# defaults/noarch::ipywidgets==7.6.5=pyhd3eb1b0_1 -> jupyterlab_widgets[version='>=1.0.0']
#
# Package qt conflicts for:
# defaults/osx-arm64::pyqt==5.15.7=py310hc377ac9_0 -> qtwebkit=5 -> qt[version='5.6.2.*|5.9.*|>=5.12.9,<5.13.0a0|>=5.9.7,<5.10.0a0']
# defaults/osx-arm64::qtconsole==5.4.0=py310hca03da5_0 -> pyqt -> qt[version='4.8.*|5.6.*|5.9.*|>=5.12.5,<5.13.0a0|>=5.12.9,<5.13.0a0|>=5.9.7,<5.10.0a0|>=5.6.2,<5.7.0a0|>=5.9.6,<5.10.0a0']
#
# Package pkgutil-resolve-name conflicts for:
# defaults/osx-arm64::nbformat==5.7.0=py310hca03da5_0 -> jsonschema[version='>=2.6'] -> pkgutil-resolve-name[version='>=1.3.10']
# defaults/osx-arm64::jupyterlab_server==2.16.5=py310hca03da5_0 -> jsonschema[version='>=3.0.1'] -> pkgutil-resolve-name[version='>=1.3.10']
#
# Package libtiff conflicts for:
# defaults/osx-arm64::libwebp==1.2.4=h68602c7_0 -> libtiff[version='>=4.2.0,<5.0a0']
# defaults/osx-arm64::qtwebkit==5.212=h0f11f3c_4 -> libwebp[version='>=1.2.0,<1.3.0a0'] -> libtiff[version='>=4.1.0,<5.0a0|>=4.2.0,<4.5.0a0|>=4.3.0,<4.5.0a0|>=4.4.0,<4.5.0a0|>=4.5.0,<4.6.0a0|>=4.2.0,<5.0a0']
#
# Package soupsieve conflicts for:
# defaults/osx-arm64::nbconvert==6.5.4=py310hca03da5_0 -> beautifulsoup4 -> soupsieve[version='>1.2|>=1.2']
# defaults/osx-arm64::beautifulsoup4==4.11.1=py310hca03da5_0 -> soupsieve[version='>=1.2']
#
# Package executing conflicts for:
# defaults/noarch::stack_data==0.2.0=pyhd3eb1b0_0 -> executing
# defaults/osx-arm64::ipython==8.8.0=py310hca03da5_0 -> stack_data -> executing
#
# Package notebook-shim conflicts for:
# defaults/osx-arm64::notebook==6.5.2=py310hca03da5_0 -> nbclassic[version='>=0.4.7'] -> notebook-shim[version='>=0.1.0|>=0.2.3']
# defaults/osx-arm64::nbclassic==0.4.8=py310hca03da5_0 -> notebook-shim[version='>=0.1.0']
# defaults/osx-arm64::jupyterlab==3.5.3=py310hca03da5_0 -> nbclassic -> notebook-shim[version='>=0.1.0|>=0.2.3']The following specifications were found to be incompatible with your system:
#
#   - feature:/osx-64::__osx==10.16=0
#   - feature:/osx-64::__unix==0=0
#   - feature:|@/osx-64::__osx==10.16=0
#   - feature:|@/osx-64::__unix==0=0
#   - defaults/noarch::ipywidgets==7.6.5=pyhd3eb1b0_1 -> ipykernel[version='>=4.5.1'] -> __linux
#   - defaults/noarch::ipywidgets==7.6.5=pyhd3eb1b0_1 -> ipykernel[version='>=4.5.1'] -> __osx
#   - defaults/noarch::ipywidgets==7.6.5=pyhd3eb1b0_1 -> ipykernel[version='>=4.5.1'] -> __win
#   - defaults/osx-arm64::ipykernel==6.19.2=py310h33ce5c2_0 -> ipython[version='>=7.23.1'] -> __linux
#   - defaults/osx-arm64::ipykernel==6.19.2=py310h33ce5c2_0 -> ipython[version='>=7.23.1'] -> __osx
#   - defaults/osx-arm64::ipykernel==6.19.2=py310h33ce5c2_0 -> ipython[version='>=7.23.1'] -> __win
#   - defaults/osx-arm64::jupyter==1.0.0=py310hca03da5_8 -> ipykernel -> __linux
#   - defaults/osx-arm64::jupyter==1.0.0=py310hca03da5_8 -> ipykernel -> __osx
#   - defaults/osx-arm64::jupyter==1.0.0=py310hca03da5_8 -> ipykernel -> __win
#   - defaults/osx-arm64::jupyter_console==6.4.4=py310hca03da5_0 -> ipykernel -> __linux
#   - defaults/osx-arm64::jupyter_console==6.4.4=py310hca03da5_0 -> ipykernel -> __osx
#   - defaults/osx-arm64::jupyter_console==6.4.4=py310hca03da5_0 -> ipykernel -> __win
#   - defaults/osx-arm64::jupyter_server==1.23.4=py310hca03da5_0 -> send2trash -> __linux
#   - defaults/osx-arm64::jupyter_server==1.23.4=py310hca03da5_0 -> send2trash -> __osx
#   - defaults/osx-arm64::jupyter_server==1.23.4=py310hca03da5_0 -> send2trash -> __win
#   - defaults/osx-arm64::jupyterlab==3.5.3=py310hca03da5_0 -> ipython -> __linux
#   - defaults/osx-arm64::jupyterlab==3.5.3=py310hca03da5_0 -> ipython -> __osx
#   - defaults/osx-arm64::jupyterlab==3.5.3=py310hca03da5_0 -> ipython -> __win
#   - defaults/osx-arm64::nbclassic==0.4.8=py310hca03da5_0 -> ipykernel -> __linux
#   - defaults/osx-arm64::nbclassic==0.4.8=py310hca03da5_0 -> ipykernel -> __osx
#   - defaults/osx-arm64::nbclassic==0.4.8=py310hca03da5_0 -> ipykernel -> __win
#   - defaults/osx-arm64::notebook==6.5.2=py310hca03da5_0 -> ipykernel -> __linux
#   - defaults/osx-arm64::notebook==6.5.2=py310hca03da5_0 -> ipykernel -> __osx
#   - defaults/osx-arm64::notebook==6.5.2=py310hca03da5_0 -> ipykernel -> __win
#   - defaults/osx-arm64::pyqt==5.15.7=py310hc377ac9_0 -> qtwebkit=5 -> __osx[version='>=10.12']
#   - defaults/osx-arm64::qtconsole==5.4.0=py310hca03da5_0 -> ipykernel[version='>=4.1'] -> __linux
#   - defaults/osx-arm64::qtconsole==5.4.0=py310hca03da5_0 -> ipykernel[version='>=4.1'] -> __osx
#   - defaults/osx-arm64::qtconsole==5.4.0=py310hca03da5_0 -> ipykernel[version='>=4.1'] -> __win
#   - defaults/osx-arm64::urllib3==1.26.13=py310hca03da5_0 -> pysocks[version='>=1.5.6,<2.0,!=1.5.7'] -> __unix
#   - defaults/osx-arm64::urllib3==1.26.13=py310hca03da5_0 -> pysocks[version='>=1.5.6,<2.0,!=1.5.7'] -> __win
#
# Your installed version is: not available
#
# Note that strict channel priority may have removed packages required for satisfiability.

# %% [markdown]
# ## Mission 2
#
# 이번 미션에서는 start codon 주변에서 ribosome-protected fragment의 분포를 한 번 살펴보겠습니다. 보통은 RPF의 5'-end 분포가 start codon 앞 15nt 정도에서부터 본격적으로 많이 나오고, 거기서부터 CDS를 걸쳐서 3nt 주기로 올록볼록한 패턴이 나타납니다.
#
# 이 그림을 제대로 그리려면 genome coordinate를 start codon을 기준으로 변환해서 작업해야 하지만, 이번 미션에서는 난이도를 적절히 내리기 위해서 start codon이 포함된 exon에 존재하는 5' end만 추려서 작업하도록 합시다. (여유가 좀 있어서 난이도를 적당히 올리고 싶은 분들은 negative strand를 포함할 수도 있고, start codon과 다른 exon에 있는 경우를 포함할 수도 있습니다. 또한 APPRIS 등을 기반으로 해서 transcript 중에 가장 )

# %%
# %cd /Users/steineggerlab/Desktop/lecture/bioinf1/binfo1-work2
# Out:
# /Users/steineggerlab/Desktop/lecture/bioinf1/binfo1-work2

# %% [markdown]
# 우선 annotation에서 start codon이 포함된 exon만 추립니다. Gene 한 개에 isoform이 여러 개 있는 경우 모두 쓰면 read가 너무 부풀려질 수 있기 때문에 우선 transcript support level이 1인 것만 추려서 사용합니다. 여전히 TSL 1만 쓰더라도 부풀려질 가능성은 있기 때문에 제대로 하자면 APPRIS나 RNA-seq 데이터 기준으로 하나만 선정하는 것이 좋습니다만, 일단 여기서는 간단히..
#
# 그리고, - strand가 들어가면 좀 계산이 복잡해지니까 또 간단하게 하기 위해서 + strand만 고릅니다. 이번엔 일단 무조건 간단하게 해 봅시다~

# %%
# !grep '	start_codon	.*	+	.*transcript_support_level "1"' gencode.gtf | \
 sed -e 's/	[^	]*transcript_id "\([^"]*\)".*$/	\1/g' > gencode-start.gtf
# !head gencode-start.gtf
# Out:
# chr1	HAVANA	start_codon	4878137	4878139	.	+	0	ENSMUST00000134384.8
# chr1	HAVANA	start_codon	4878137	4878139	.	+	0	ENSMUST00000027036.11
# chr1	HAVANA	start_codon	4878137	4878139	.	+	0	ENSMUST00000150971.8
# chr1	HAVANA	start_codon	4928137	4928139	.	+	0	ENSMUST00000081551.14
# chr1	HAVANA	start_codon	5154674	5154676	.	+	0	ENSMUST00000044369.13
# chr1	HAVANA	start_codon	5659272	5659274	.	+	0	ENSMUST00000160777.8
# chr1	HAVANA	start_codon	5659272	5659274	.	+	0	ENSMUST00000027038.11
# chr1	HAVANA	start_codon	6300227	6300229	.	+	0	ENSMUST00000027040.13
# chr1	HAVANA	start_codon	6429555	6429557	.	+	0	ENSMUST00000133144.4
# chr1	HAVANA	start_codon	6839122	6839124	.	+	0	ENSMUST00000140079.8

# %% [markdown]
# start codon가 들어가 있는 exon들을 고르기 위해서 미리 + strand에 있는 exon를 추립니다.. start codon 쪽에서 TSL 기준으로 골랐기 때문에 여기서는 고르지 않아도 됩니다. 물론 좀 느려지기는 하지만...

# %%
# 아래 공백 중 일부는 "탭(Tab)" 문자입니다. 입력하기 힘들 때는 텍스트 편집기에서 입력해서 복사&붙여넣기 하면 됩니다.
# !grep '	exon	.*	+	' gencode.gtf | \
 sed -e 's/	[^	]*transcript_id "\([^"]*\)".*$/	\1/g' > gencode-plusexon.gtf
# !head gencode-plusexon.gtf
# Out:
# chr1	HAVANA	exon	3143476	3144545	.	+	.	ENSMUST00000193812.2
# chr1	ENSEMBL	exon	3172239	3172348	.	+	.	ENSMUST00000082908.3
# chr1	HAVANA	exon	3322980	3323459	.	+	.	ENSMUST00000192857.2
# chr1	HAVANA	exon	3536810	3536910	.	+	.	ENSMUST00000161581.2
# chr1	HAVANA	exon	3583628	3583776	.	+	.	ENSMUST00000161581.2
# chr1	HAVANA	exon	3602018	3602943	.	+	.	ENSMUST00000192183.2
# chr1	HAVANA	exon	3750378	3752011	.	+	.	ENSMUST00000193244.2
# chr1	HAVANA	exon	3822233	3824583	.	+	.	ENSMUST00000194454.2
# chr1	HAVANA	exon	4566774	4569601	.	+	.	ENSMUST00000193450.2
# chr1	HAVANA	exon	4567697	4567877	.	+	.	ENSMUST00000194935.2

# %% [markdown]
# 그 다음엔 exon 리스트와 start codon 리스트를 겹치고, transcript가 같은 것만 살려둡니다. 기왕 좀 다루기 쉽도록 출력은 bed로 하면서 좌표계를 바꿉니다. 결과는 bedtools에서 빠르게 다룰 수 있게 sort해 둡니다.

# %%
# 아래 공백 중 일부는 "탭(Tab)" 문자입니다. 입력하기 힘들 때는 텍스트 편집기에서 입력해서 복사&붙여넣기 하면 됩니다.
# !bedtools intersect -a gencode-start.gtf -b gencode-plusexon.gtf -wa -wb | \
 awk -F'	' -v OFS='	' '$9 == $18 { print $10, $13-1, $14, $18, $4-1, $16; }' | \
 sort -k1,1 -k2,3n -k4,4 > gencode-exons-containing-startcodon.bed
# !head gencode-exons-containing-startcodon.bed; tail gencode-exons-containing-startcodon.bed
# Out:
# chr1	4878010	4878205	ENSMUST00000134384.8	4878136	+
# chr1	4878045	4878205	ENSMUST00000027036.11	4878136	+
# chr1	4878052	4878205	ENSMUST00000150971.8	4878136	+
# chr1	4928036	4928199	ENSMUST00000081551.14	4928136	+
# chr1	5154639	5154786	ENSMUST00000044369.13	5154673	+
# chr1	5659227	5659528	ENSMUST00000027038.11	5659271	+
# chr1	5659257	5659528	ENSMUST00000160777.8	5659271	+
# chr1	6300182	6300297	ENSMUST00000027040.13	6300226	+
# chr1	6429441	6429738	ENSMUST00000133144.4	6429554	+
# chr1	6839121	6839176	ENSMUST00000043578.13	6839121	+
# chrY	80939672	80939804	ENSMUST00000185340.2	80939686	+
# chrY	81470683	81470815	ENSMUST00000187135.2	81470697	+
# chrY	82237903	82238035	ENSMUST00000185636.2	82237917	+
# chrY	83043623	83043755	ENSMUST00000187165.2	83043637	+
# chrY	84109956	84110088	ENSMUST00000185776.7	84109970	+
# chrY	84759361	84759493	ENSMUST00000186110.2	84759375	+
# chrY	86074448	86074580	ENSMUST00000188754.2	86074462	+
# chrY	87129500	87129632	ENSMUST00000189543.7	87129514	+
# chrY	87563647	87563779	ENSMUST00000186493.2	87563661	+
# chrY	88065992	88066124	ENSMUST00000187146.2	88066006	+

# %% [markdown]
# 컬럼 4번에 transcript id, 5번에 start codon 위치를 넣었는데, start codon이 같은 것들이 여러개 눈에 띕니다. 아주 찝찝하지만, 우선 이번은 간단하게 할 것이기 때문에 눈을 질끈 감고 넘어가 봅시다.
#
# 이제 alignment를 준비합니다. + strand alignment에서 read length가 짧은 것도 미리 필터링 합니다. RPF는 보통 25nt 이상이기 때문에 그 이하는 거의 확실히 rRNA, tRNA 등에서 오염된 것들입니다. SAM 파일 전체를 필터링해서 다시 인코딩하기 때문에 시간이 좀 걸립니다.
#
# 오래걸리는 작업을 돌릴 떄에는 CPU 사용량, 디스크 사용량을 계속 관찰하는 것이 좋습니다. 직접 접속할 수 있는 컴퓨터에서는 `htop` 등의 명령을 쓰면 되고, Colab에서는 오른쪽 위의 메뉴에서 Resources를 띄우면 되는데, 여기서는 CPU 사용량은 보기 힘듭니다.

# %%
!(samtools view -H RPF-siLuc.bam; \
  samtools view -F20 RPF-siLuc.bam | \
  bioawk -c sam '{ if (length($seq) >= 25) print $0; }') | \
 samtools view -b -o filtered-RPF-siLuc.bam

# %% [markdown]
# 큰 일을 했으니 용량을 한 번 봅니다.

# %%
# !ls -al *RPF-siLuc.bam
# Out:
# -rw-r--r--  1 steineggerlab  staff  1055123479 May  7 15:00 RPF-siLuc.bam
# -rw-r--r--  1 steineggerlab  staff   554373643 May  7 17:30 filtered-RPF-siLuc.bam

# %% [markdown]
# 자 이제 read의 5' end 위치를 셉니다. bedtools의 `genomecov`를 쓰면 아주 편리합니다.

# %%
# !bedtools genomecov -ibam filtered-RPF-siLuc.bam -bg -5 > fivepcounts-RPF-siLuc.bed
# !head fivepcounts-RPF-siLuc.bed
# Out:
# chr1	3176534	3176535	1
# chr1	3196256	3196257	1
# chr1	3221526	3221527	1
# chr1	3221542	3221543	2
# chr1	3221545	3221546	3
# chr1	3221546	3221547	2
# chr1	3221548	3221550	1
# chr1	3221571	3221572	1
# chr1	3221897	3221898	1
# chr1	3221994	3221995	1

# %% [markdown]
# 그렇게 match 된 것들 중에 앞에서 찾은 start codon을 포함한 exon과 겹치는 것만 골라냅니다.

# %%
# !bedtools intersect -a fivepcounts-RPF-siLuc.bed -b gencode-exons-containing-startcodon.bed \
 -wa -wb -nonamecheck > fivepcounts-filtered-RPF-siLuc.txt
# !head fivepcounts-filtered-RPF-siLuc.txt
# Out:
# chr1	4878048	4878049	1	chr1	4878010	4878205	ENSMUST00000134384.8	4878136	+
# chr1	4878048	4878049	1	chr1	4878045	4878205	ENSMUST00000027036.11	4878136	+
# chr1	4878077	4878078	1	chr1	4878010	4878205	ENSMUST00000134384.8	4878136	+
# chr1	4878077	4878078	1	chr1	4878045	4878205	ENSMUST00000027036.11	4878136	+
# chr1	4878077	4878078	1	chr1	4878052	4878205	ENSMUST00000150971.8	4878136	+
# chr1	4878101	4878102	4	chr1	4878010	4878205	ENSMUST00000134384.8	4878136	+
# chr1	4878101	4878102	4	chr1	4878045	4878205	ENSMUST00000027036.11	4878136	+
# chr1	4878101	4878102	4	chr1	4878052	4878205	ENSMUST00000150971.8	4878136	+
# chr1	4878103	4878104	1	chr1	4878010	4878205	ENSMUST00000134384.8	4878136	+
# chr1	4878103	4878104	1	chr1	4878045	4878205	ENSMUST00000027036.11	4878136	+

# %% [markdown]
# 모든 준비가 끝났습니다. 이제 Figure S5A 도전해 보세요!
#
# * stop codon은 빼고 start codon 만입니다.
# * 논문에서는 처리가 어려운 부분까지 모두 포함됐고, read를 중첩해서 세지 않았기 때문에, 여기서 세는 것과는 수치는 다를 수 있습니다.
# * `pandas`로 한꺼번에 데이터를 모두 불러들이면 메모리가 부족할 수도 있습니다. 그런 경우에는 chunk를 쓰거나, 줄 단위로 처리해 보세요.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

siluc = pd.read_csv('fivepcounts-filtered-RPF-siLuc.txt', sep='\t', header=None)
siluc.columns = ['chrom', 'read_start', 'read_end', 'count', 'chrom2', 'exon_start', 'exon_end', 'transcript', 'start_codon', 'strand']

siluc['diff'] = (siluc['read_start'] - siluc['start_codon'])

# %%
diff_long = []
for i in range(len(siluc['diff'])):
    diff_long.extend([siluc['diff'][i]]*siluc['count'][i])

# %%
fig = plt.figure(figsize=(10, 3), dpi=300)
ax = fig.add_subplot(1, 1, 1)

sns.histplot(diff_long, bins=range(-50, 50), kde=False, color='gray', ax=ax)
ax.set_xlim(-50, 50)
ax.set_xlabel("Relative position to start codon of 5'-end of reads")
ax.set_ylabel("siLuc")
ax.set_xticks([-50, -40, -30, -20, -10, 0, 10, 20, 30, 40, 50])
ax.set_xticklabels([-50, -40, -30, -20, -10, 0, 10, 20, 30, 40, 50])
# Out:
# [Text(-50, 0, '-50'),
#  Text(-40, 0, '-40'),
#  Text(-30, 0, '-30'),
#  Text(-20, 0, '-20'),
#  Text(-10, 0, '-10'),
#  Text(0, 0, '0'),
#  Text(10, 0, '10'),
#  Text(20, 0, '20'),
#  Text(30, 0, '30'),
#  Text(40, 0, '40'),
#  Text(50, 0, '50')]
